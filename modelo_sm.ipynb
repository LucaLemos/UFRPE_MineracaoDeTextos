# %%
import spacy
import random
import jsonlines
from spacy.training import Example, offsets_to_biluo_tags
from spacy.tokens import DocBin
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
import os

# %%
# Load the SpaCy model
nlp = spacy.load("pt_core_news_sm")

# %%
data = []
with jsonlines.open('dataset.jsonl', 'r') as reader:
    for line in reader:
        data.append(line)

# %%
# Shuffle the dataset to randomize the order
random.shuffle(data)

# %%
# Function to adjust entity spans according to SpaCy's token boundaries
def adjust_entity_spans(doc, entities):
    adjusted_entities = []
    for start, end, label in entities:
        span = doc.char_span(start, end, label=label)
        if span is not None:
            adjusted_entities.append((span.start_char, span.end_char, label))
    return adjusted_entities

# %%
# Convert the dataset to SpaCy format and adjust entity spans
def convert_data_for_spacy(data, nlp):
    spacy_format = []
    for item in data:
        text = item['text']
        doc = nlp.make_doc(text)
        entities = adjust_entity_spans(doc, item['label'])
        spacy_format.append((text, {"entities": entities}))
    return spacy_format

# %%
# Split the data into training and test sets
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# Convert and adjust the training and test data
training_data = convert_data_for_spacy(train_data, nlp)
test_data_spacy = convert_data_for_spacy(test_data, nlp)

# %%
# Add the NER pipeline if not already present
if 'ner' not in nlp.pipe_names:
    ner = nlp.add_pipe('ner')
else:
    ner = nlp.get_pipe('ner')

# Add custom labels to the NER component
for _, annotations in training_data:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

# %%
# Disable other pipeline components during training
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']

# %%
# Fine-tune the model
with nlp.disable_pipes(*unaffected_pipes):
    optimizer = nlp.resume_training()
    for iteration in range(20):  # You can change the number of iterations
        random.shuffle(training_data)
        losses = {}
        for text, annotations in training_data:
            example = Example.from_dict(nlp.make_doc(text), annotations)
            nlp.update([example], drop=0.5, losses=losses)
        print(f"Iteration {iteration + 1}, Losses: {losses}")
# Out:
# Iteration 1, Losses: {'ner': 2668.9379402744116}
# Iteration 2, Losses: {'ner': 1783.0122555730406}
# Iteration 3, Losses: {'ner': 1522.755116702746}
# Iteration 4, Losses: {'ner': 1413.0859480122726}
# Iteration 5, Losses: {'ner': 1298.0295452832959}
# Iteration 6, Losses: {'ner': 1254.0821492908017}
# Iteration 7, Losses: {'ner': 1158.2312676711963}
# Iteration 8, Losses: {'ner': 1145.6000367498061}
# Iteration 9, Losses: {'ner': 1085.2465623528688}
# Iteration 10, Losses: {'ner': 998.3618262109056}
# Iteration 11, Losses: {'ner': 966.9168154318679}
# Iteration 12, Losses: {'ner': 959.5886045900882}
# Iteration 13, Losses: {'ner': 937.3116329223598}
# Iteration 14, Losses: {'ner': 908.6292592632087}
# Iteration 15, Losses: {'ner': 863.9349467169569}
# Iteration 16, Losses: {'ner': 832.4097065164898}
# Iteration 17, Losses: {'ner': 768.4486479955392}
# Iteration 18, Losses: {'ner': 836.4067834722406}
# Iteration 19, Losses: {'ner': 757.6957499654941}
# Iteration 20, Losses: {'ner': 786.9169786333001}

# %%
# Save the fine-tuned model
output_dir = "3VA/model_sm"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
nlp.to_disk(output_dir)
print(f"Model saved to {output_dir}")
# Out:
# Model saved to 3VA/model_sm

# %%
# Test the fine-tuned model
nlp = spacy.load(output_dir)

# %%
# Initialize lists for true and predicted labels
true_labels = []
pred_labels = []

for text, annotations in test_data_spacy:
    doc = nlp(text)
    pred_entities = [(ent.start_char, ent.end_char, ent.label_) for ent in doc.ents]
    true_entities = annotations["entities"]

    # Print entities for debugging
    print(text)
    print(doc.ents)
    print("Predicted:", pred_entities)
    print("True:", true_entities)
    print("\n")

    # Create a dictionary to store the predicted and true labels with their spans
    pred_dict = {(start, end): label for start, end, label in pred_entities}
    true_dict = {(start, end): label for start, end, label in true_entities}

    # Union of all spans (keys) from both true and predicted dictionaries
    all_spans = set(pred_dict.keys()).union(set(true_dict.keys()))

    # Compare the labels based on spans
    for span in all_spans:
        true_labels.append(true_dict.get(span, "O"))  # "O" represents no entity in the true labels
        pred_labels.append(pred_dict.get(span, "O"))  # "O" represents no entity in the predicted labels

# Calculate precision, recall, and F1-score
print(classification_report(true_labels, pred_labels))
# Out:
# Fone de Ouvido Bluetooth JBL Tune 510BT Preto JBLT510BTBLK
# (Fone de Ouvido, Bluetooth, JBL, Tune 510BT, Preto, JBLT510BTBLK)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 28, 'Marca'), (29, 39, 'Modelo'), (40, 45, 'Cor'), (46, 58, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 28, 'Marca'), (29, 39, 'Modelo'), (40, 45, 'Cor'), (46, 58, 'Modelo')]
#
#
# Over Ear Stereo Áudio - PH148
# (Over Ear, Stereo, Áudio, PH148)
# Predicted: [(0, 8, 'Categoria'), (9, 15, 'Caracteristicas'), (16, 21, 'Caracteristicas'), (24, 29, 'Modelo')]
# True: [(0, 8, 'Categoria'), (9, 15, 'Caracteristicas'), (16, 21, 'Caracteristicas'), (24, 29, 'Modelo')]
#
#
# Fone de Ouvido Intra-auricular c/ Microfone
# (Fone de Ouvido, Intra-auricular, c/ Microfone)
# Predicted: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 43, 'Caracteristicas')]
# True: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 43, 'Caracteristicas')]
#
#
# Pulse Wi-fi Speaker Smarty - SP358
# (Pulse, Wi-fi Speaker, Smarty, SP358)
# Predicted: [(0, 5, 'Marca'), (6, 19, 'Modelo'), (20, 26, 'Marca'), (29, 34, 'Modelo')]
# True: [(0, 5, 'Marca'), (6, 11, 'Conectividade'), (12, 19, 'Categoria'), (20, 34, 'Modelo')]
#
#
# Headset Gamer Trust GXT 310D Radius PS4 / PS5 / XBOX series / SWITCH / PC-Desert -T22208
# (Headset, Gamer, Trust, GXT 310D, PS4, PS5, XBOX, SWITCH, PC-Desert)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 19, 'Marca'), (20, 28, 'Modelo'), (36, 39, 'Conectividade'), (42, 45, 'Conectividade'), (48, 52, 'Conectividade'), (62, 68, 'Conectividade'), (71, 80, 'Conectividade')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 19, 'Marca'), (20, 35, 'Modelo'), (36, 39, 'Conectividade'), (42, 45, 'Conectividade'), (48, 59, 'Conectividade'), (62, 68, 'Conectividade')]
#
#
# Caixa de Som JBL PartyBox On-The-Go 100W Bluetooth Preta
# (Caixa de Som, JBL, PartyBox, On-The-Go, 100W, Bluetooth, Preta)
# Predicted: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 25, 'Modelo'), (26, 35, 'Modelo'), (36, 40, 'Potência'), (41, 50, 'Conectividade'), (51, 56, 'Cor')]
# True: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 35, 'Modelo'), (36, 40, 'Potência'), (41, 50, 'Conectividade'), (51, 56, 'Cor')]
#
#
# Headset Gamer Sony Pulse 3D para PS5
# (Headset, Gamer, Pulse, 3D para, PS5)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (19, 24, 'Marca'), (25, 32, 'Potência'), (33, 36, 'Conectividade')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 18, 'Marca'), (19, 24, 'Marca'), (25, 27, 'Caracteristicas'), (33, 36, 'Conectividade')]
#
#
# Headset Gamer HyperX Cloud Alpha - HX-HSCA-RD/AM
# (Headset, Gamer, HyperX, Cloud Alpha, HX-HSCA-RD/AM)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (21, 32, 'Modelo'), (35, 48, 'Modelo')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (21, 32, 'Modelo'), (35, 48, 'Modelo')]
#
#
# Projetor Goldentec GT3500 Full HD 3500 Lumens com 2 HDMI, AV, VGA + Tela de Projeção Retrátil Goldentec 200x150 cm
# (Projetor, Goldentec, GT3500, com 2, HDMI, AV, VGA, Tela de Projeção, Retrátil, Goldentec)
# Predicted: [(0, 8, 'Categoria'), (9, 18, 'Marca'), (19, 25, 'Modelo'), (46, 51, 'Caracteristicas'), (52, 56, 'Conectividade'), (58, 60, 'Conectividade'), (62, 65, 'Conectividade'), (68, 84, 'Caracteristicas'), (85, 93, 'Caracteristicas'), (94, 103, 'Marca')]
# True: [(0, 8, 'Categoria'), (9, 18, 'Marca'), (19, 33, 'Modelo'), (34, 45, 'Potência'), (52, 56, 'Conectividade'), (58, 60, 'Conectividade'), (62, 65, 'Conectividade'), (68, 84, 'Categoria'), (85, 93, 'Caracteristicas'), (94, 103, 'Marca'), (104, 114, 'Tamanho')]
#
#
# Fone de Ouvido Auricular Bluetooth JBL Tune 215BT Pure Bass Hands-Free com Microfone, Preto-JBLT215BTBLK
# (Fone de Ouvido, Auricular, Bluetooth, JBL, Tune 215BT, Pure Bass, Hands-Free, com Microfone)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 34, 'Conectividade'), (35, 38, 'Marca'), (39, 49, 'Modelo'), (50, 59, 'Caracteristicas'), (60, 70, 'Caracteristicas'), (71, 84, 'Caracteristicas')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 34, 'Conectividade'), (35, 38, 'Marca'), (39, 49, 'Modelo'), (50, 59, 'Caracteristicas'), (60, 70, 'Caracteristicas'), (71, 84, 'Item adicional')]
#
#
# Fone de Ouvido Auricular JBL Bluetooth 300 Wave TWS, Branco - JBLW300TWSWHT
# (Fone de Ouvido, Auricular, JBL, Bluetooth, Wave TWS, Branco, JBLW300TWSWHT)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (43, 51, 'Modelo'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (39, 47, 'Modelo'), (48, 51, 'Conectividade'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
#
#
# Fone de Ouvido Multilaser Play Som Estéreo Azul - PH314
# (Fone de Ouvido, Multilaser, Play Som Estéreo, Azul, PH314)
# Predicted: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 42, 'Modelo'), (43, 47, 'Cor'), (50, 55, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 30, 'Modelo'), (31, 42, 'Caracteristicas'), (43, 47, 'Cor'), (50, 55, 'Modelo')]
#
#
# Caixa De Som Amplificadora Multilaser Trolley 150W Rms Com Alça - SP200
# (Caixa De Som, Amplificadora, Multilaser, Trolley, 150W, Com Alça, SP200)
# Predicted: [(0, 12, 'Categoria'), (13, 26, 'Tipo'), (27, 37, 'Marca'), (38, 45, 'Modelo'), (46, 50, 'Potência'), (55, 63, 'Caracteristicas'), (66, 71, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 26, 'Tipo'), (27, 37, 'Marca'), (38, 45, 'Modelo'), (46, 54, 'Potência'), (55, 63, 'Item adicional'), (66, 71, 'Modelo')]
#
#
# Caixa de Som Portátil JBL Clip 4 Bluetooth 5W À Prova D'água e Poeira IP67 Azul
# (Caixa de Som, Portátil, JBL, Clip 4, Bluetooth, 5W, À Prova D'água e Poeira, IP67, Azul)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 32, 'Modelo'), (33, 42, 'Conectividade'), (43, 45, 'Potência'), (46, 69, 'Caracteristicas'), (70, 74, 'Caracteristicas'), (75, 79, 'Cor')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 32, 'Modelo'), (33, 42, 'Conectividade'), (43, 45, 'Potência'), (46, 69, 'Caracteristicas'), (70, 74, 'Caracteristicas'), (75, 79, 'Cor')]
#
#
# Fone de Ouvido Auricular JBL Bluetooth 300 Wave TWS, Branco - JBLW300TWSWHT
# (Fone de Ouvido, Auricular, JBL, Bluetooth, Wave TWS, Branco, JBLW300TWSWHT)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (43, 51, 'Modelo'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
# True: [(0, 24, 'Categoria'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (39, 47, 'Modelo'), (48, 51, 'Conectividade'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
#
#
# Caixa de Som portátil JBL Partybox 100 Bluetooth USB
# (Caixa de Som, portátil, JBL, Partybox 100, Bluetooth, USB)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 38, 'Modelo'), (39, 48, 'Conectividade'), (49, 52, 'Conectividade')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 38, 'Modelo'), (39, 48, 'Conectividade'), (49, 52, 'Conectividade')]
#
#
# Fone de Ouvido Intra-Auricular Bluetooth JBL Tune 125BT, Branco-JBLT125BTWHT
# (Fone de Ouvido, Intra-Auricular, Bluetooth, JBL, Tune 125BT)
# Predicted: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
#
#
# Mini Torre Neon 2 Led Rgb 250w Bt/Sd/Fm/Aux/Tws Multilaser – SP400
# (Mini Torre, Led Rgb, 250w, Bt, Fm, Aux/, Multilaser, SP400)
# Predicted: [(0, 10, 'Categoria'), (18, 25, 'Caracteristicas'), (26, 30, 'Potência'), (31, 33, 'Conectividade'), (37, 39, 'Conectividade'), (40, 44, 'Conectividade'), (48, 58, 'Marca'), (61, 66, 'Modelo')]
# True: [(0, 10, 'Categoria'), (16, 25, 'Caracteristicas'), (26, 30, 'Potência'), (31, 47, 'Conectividade'), (48, 58, 'Marca'), (61, 66, 'Modelo')]
#
#
# Caixa de Som Wave 3 20W Bluetooth Pulse - SP608
# (Caixa de Som, Wave 3, 20W, Bluetooth, Pulse, SP608)
# Predicted: [(0, 12, 'Categoria'), (13, 19, 'Modelo'), (20, 23, 'Potência'), (24, 33, 'Conectividade'), (34, 39, 'Marca'), (42, 47, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 19, 'Modelo'), (20, 23, 'Potência'), (24, 33, 'Conectividade'), (34, 39, 'Marca'), (42, 47, 'Modelo')]
#
#
# Rádio Relógio Multilaser - SP352
# (Rádio Relógio, Multilaser, SP352)
# Predicted: [(0, 13, 'Categoria'), (14, 24, 'Marca'), (27, 32, 'Modelo')]
# True: [(0, 13, 'Categoria'), (14, 24, 'Marca'), (27, 32, 'Modelo')]
#
#
# Caixa De Som Multilaser 250W RMS Ativa 15 Polegadas Bt/Usb/Fm/Aux/Mic - SP297
# (Multilaser, 250W RMS, Ativa 15 Polegadas, Bt, Usb, Fm, Aux/, SP297)
# Predicted: [(13, 23, 'Marca'), (24, 32, 'Potência'), (33, 51, 'Caracteristicas'), (52, 54, 'Conectividade'), (55, 58, 'Conectividade'), (59, 61, 'Conectividade'), (62, 66, 'Conectividade'), (72, 77, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 23, 'Marca'), (24, 32, 'Potência'), (33, 38, 'Caracteristicas'), (39, 51, 'Tamanho'), (52, 69, 'Conectividade'), (72, 77, 'Modelo')]
#
#
# Caixa De Som Monster High Speaker Multikids- SP170
# (Caixa De Som, Monster High, Speaker, SP170)
# Predicted: [(0, 12, 'Categoria'), (13, 25, 'Modelo'), (26, 33, 'Categoria'), (45, 50, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 25, 'Modelo'), (26, 33, 'Categoria'), (45, 50, 'Modelo')]
#
#
# Earhook Pro Intra-Auricular Preto Multilaser - PH356
# (Earhook Pro, Intra-Auricular, Preto, Multilaser, PH356)
# Predicted: [(0, 11, 'Categoria'), (12, 27, 'Tipo'), (28, 33, 'Cor'), (34, 44, 'Marca'), (47, 52, 'Modelo')]
# True: [(0, 7, 'Categoria'), (12, 27, 'Tipo'), (28, 33, 'Cor'), (34, 44, 'Marca'), (47, 52, 'Modelo')]
#
#
# Mini Projetor 2000 Lumens SVGA PCTop GP80 com HDMI - Branco
# (Mini Projetor, SVGA, PCTop, GP80, HDMI, Branco)
# Predicted: [(0, 13, 'Categoria'), (26, 30, 'Modelo'), (31, 36, 'Modelo'), (37, 41, 'Modelo'), (46, 50, 'Conectividade'), (53, 59, 'Cor')]
# True: [(0, 13, 'Categoria'), (14, 25, 'Potência'), (26, 30, 'Conectividade'), (31, 36, 'Marca'), (37, 41, 'Modelo'), (46, 50, 'Conectividade'), (53, 59, 'Cor')]
#
#
# Caixa de Som ObaSound Pool Obabox - OB008
# (Caixa de Som, ObaSound Pool, Obabox, OB008)
# Predicted: [(0, 12, 'Categoria'), (13, 26, 'Modelo'), (27, 33, 'Marca'), (36, 41, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 26, 'Modelo'), (27, 33, 'Marca')]
#
#
# Caixa Ativa 15 Pol 250W PulsePRO - SP371
# (Caixa Ativa 15, 250W, PulsePRO, SP371)
# Predicted: [(0, 14, 'Categoria'), (19, 23, 'Potência'), (24, 32, 'Modelo'), (35, 40, 'Modelo')]
# True: [(0, 11, 'Categoria'), (12, 18, 'Tamanho'), (19, 23, 'Potência'), (24, 32, 'Marca'), (35, 40, 'Modelo')]
#
#
# Amplificador Frahm Profissional GR 5000
# (Amplificador, Frahm, Profissional GR)
# Predicted: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 34, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 39, 'Modelo')]
#
#
# Caixa de Som Gamer Warrior Odysseus P2 2.1 50W RMS Com Subwoofer - SP266
# (Caixa de Som, Gamer, Warrior, Odysseus, P2, 50W RMS, Com Subwoofer, SP266)
# Predicted: [(0, 12, 'Categoria'), (13, 18, 'Caracteristicas'), (19, 26, 'Caracteristicas'), (27, 35, 'Marca'), (36, 38, 'Conectividade'), (43, 50, 'Potência'), (51, 64, 'Item adicional'), (67, 72, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 18, 'Caracteristicas'), (36, 38, 'Conectividade'), (39, 42, 'Modelo'), (43, 50, 'Potência'), (51, 64, 'Item adicional'), (67, 72, 'Modelo')]
#
#
# Fone de Ouvido Xiaomi Mi True Bluetooth Wireless Earbuds Basic S, Preto- XM522PRE
# (Fone de Ouvido, Xiaomi, Mi True, Bluetooth, Wireless Earbuds, XM522PRE)
# Predicted: [(0, 14, 'Categoria'), (15, 21, 'Marca'), (22, 29, 'Modelo'), (30, 39, 'Conectividade'), (40, 56, 'Modelo'), (73, 81, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Marca'), (25, 29, 'Modelo'), (30, 39, 'Conectividade'), (40, 48, 'Conectividade'), (49, 62, 'Modelo'), (66, 81, 'Caracteristicas')]
#
#
# Caixa de Som Multilaser Mini Torre 900W BT/AUX/USB/FM - SP380 (127 V)
# (Caixa de Som, Multilaser, Mini, Torre, 900W, BT/, AUX, USB, SP380, 127 V)
# Predicted: [(0, 12, 'Categoria'), (13, 23, 'Marca'), (24, 28, 'Modelo'), (29, 34, 'Categoria'), (35, 39, 'Potência'), (40, 43, 'Conectividade'), (43, 46, 'Conectividade'), (47, 50, 'Conectividade'), (56, 61, 'Modelo'), (63, 68, 'Potência')]
# True: [(0, 12, 'Categoria'), (24, 34, 'Modelo'), (35, 39, 'Potência')]
#
#
# Fone de Ouvido Auricular JBL Wave 200TWS, Azul - JBLW200TWSBLU
# (Fone de Ouvido, Auricular, JBL, Wave 200TWS, Azul, JBLW200TWSBLU)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 40, 'Modelo'), (42, 46, 'Cor'), (49, 62, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 40, 'Modelo'), (42, 46, 'Cor'), (49, 62, 'Modelo')]
#
#
# Caixa Amplificada Frahm CM 300 BT Multiuso, Portátil, USB, Bluetooth - Bivolt
# (Caixa Amplificada, Frahm, 300 BT, Multiuso, Portátil, USB, Bluetooth, Bivolt)
# Predicted: [(0, 17, 'Categoria'), (18, 23, 'Marca'), (27, 33, 'Potência'), (34, 42, 'Marca'), (44, 52, 'Tipo'), (54, 57, 'Conectividade'), (59, 68, 'Conectividade'), (71, 77, 'Tensão')]
# True: [(0, 17, 'Categoria'), (18, 23, 'Marca'), (24, 33, 'Modelo'), (34, 42, 'Marca'), (44, 52, 'Tipo'), (54, 57, 'Conectividade'), (59, 68, 'Conectividade'), (71, 77, 'Tensão')]
#
#
# Caixa de Som Multilaser Mini Torre Party TWS Bluetooth 200W RMS Preto – SP336
# (Caixa de Som, Multilaser, Mini, Party, TWS, Bluetooth, 200W RMS, Preto, SP336)
# Predicted: [(0, 12, 'Categoria'), (13, 23, 'Marca'), (24, 28, 'Modelo'), (35, 40, 'Conectividade'), (41, 44, 'Conectividade'), (45, 54, 'Conectividade'), (55, 63, 'Potência'), (64, 69, 'Cor'), (72, 77, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 23, 'Marca'), (24, 34, 'Modelo'), (35, 44, 'Modelo'), (45, 54, 'Conectividade'), (55, 63, 'Potência'), (64, 69, 'Cor'), (72, 77, 'Modelo')]
#
#
# Fone de Ouvido Intra-Auricular Bluetooth JBL Tune 125BT, Branco-JBLT125BTWHT
# (Fone de Ouvido, Intra-Auricular, Bluetooth, JBL, Tune 125BT)
# Predicted: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (45, 55, 'Modelo')]
#
#
# Headset Rapoo Usb H120 - RA020
# (Headset, Rapoo, Usb, H120, RA020)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Marca'), (14, 17, 'Conectividade'), (18, 22, 'Modelo'), (25, 30, 'Modelo')]
# True: [(0, 7, 'Categoria'), (14, 17, 'Conectividade'), (25, 30, 'Modelo')]
#
#
# Headset Gamer HyperX CloudX  Xbox Preto e Cinza HHSC2-CG-SL/G
# (Headset, Gamer, HyperX, CloudX, Xbox, Preto e Cinza)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (21, 27, 'Modelo'), (29, 33, 'Modelo'), (34, 47, 'Cor')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (21, 27, 'Modelo'), (29, 33, 'Conectividade'), (34, 47, 'Cor')]
#
#
# Caixa de Som JBL PartyBox 110 160W RMS Bluetooth LED Bateria 12h
# (Caixa de Som, JBL, 160W RMS, Bluetooth, LED, Bateria 12h)
# Predicted: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (30, 38, 'Potência'), (39, 48, 'Conectividade'), (49, 52, 'Caracteristicas'), (53, 64, 'Caracteristicas')]
# True: [(0, 12, 'Categoria'), (17, 29, 'Modelo'), (30, 38, 'Potência'), (39, 48, 'Conectividade')]
#
#
# Projetor 3500 Lumens Full HD com HDMI, USB, AV e VGA | GT
# (Projetor, 3500, Full HD, HDMI, USB, AV, VGA, GT)
# Predicted: [(0, 8, 'Categoria'), (9, 13, 'Potência'), (21, 28, 'Caracteristicas'), (33, 37, 'Conectividade'), (39, 42, 'Conectividade'), (44, 46, 'Conectividade'), (49, 52, 'Conectividade'), (55, 57, 'Marca')]
# True: [(0, 8, 'Categoria'), (9, 20, 'Potência'), (21, 28, 'Caracteristicas'), (33, 37, 'Conectividade'), (39, 42, 'Conectividade'), (44, 46, 'Conectividade'), (49, 52, 'Conectividade'), (55, 57, 'Marca')]
#
#
# Caixa De Som Pulse Mini Bluetooth/Sd/P2 10W Rms Roxo E Rosa - SP239
# (Caixa De Som, Pulse, Mini, Bluetooth/, 10W Rms, Roxo E Rosa, SP239)
# Predicted: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 23, 'Modelo'), (24, 34, 'Conectividade'), (40, 47, 'Potência'), (48, 59, 'Cor'), (62, 67, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 23, 'Modelo'), (24, 39, 'Conectividade'), (40, 47, 'Potência'), (48, 52, 'Cor'), (55, 59, 'Cor'), (62, 67, 'Modelo')]
#
#
# Fone De Ouvido Silicone Earhook Pulse Preto/Azul - PH220
# (Fone, Silicone, Earhook, Pulse, Preto/Azul, PH220)
# Predicted: [(0, 4, 'Categoria'), (15, 23, 'Caracteristicas'), (24, 31, 'Caracteristicas'), (32, 37, 'Marca'), (38, 48, 'Cor'), (51, 56, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 23, 'Caracteristicas'), (24, 31, 'Modelo'), (32, 37, 'Marca'), (38, 48, 'Cor'), (51, 56, 'Modelo')]
#
#
# MP4 8GB LCD 1.8
# (MP4, 8GB, LCD 1.8)
# Predicted: [(0, 3, 'Categoria'), (4, 7, 'Caracteristicas'), (8, 15, 'Caracteristicas')]
# True: [(0, 3, 'Categoria'), (4, 15, 'Caracteristicas')]
#
#
# Headset Sem Fio Gamer HyperX Cloud Flight, LED, Drivers 50mm, Preto - HX-HSCF-BK/AM
# (Headset, Sem Fio, Gamer, HyperX, Cloud Flight, LED, Drivers 50mm, Preto, HX-HSCF-BK/AM)
# Predicted: [(0, 7, 'Categoria'), (8, 15, 'Tipo'), (16, 21, 'Caracteristicas'), (22, 28, 'Marca'), (29, 41, 'Modelo'), (43, 46, 'Caracteristicas'), (48, 60, 'Caracteristicas'), (62, 67, 'Cor'), (70, 83, 'Modelo')]
# True: [(0, 7, 'Categoria'), (8, 15, 'Tipo'), (16, 21, 'Caracteristicas'), (22, 28, 'Marca'), (29, 41, 'Modelo'), (43, 46, 'Caracteristicas'), (48, 60, 'Caracteristicas'), (62, 67, 'Cor'), (70, 83, 'Modelo')]
#
#
# Fone JBL TWS Wave Buds, Auricular, Bluetooth, Preto - JBLWBUDSBLK
# (Fone, JBL, TWS Wave Buds, Auricular, Bluetooth, Preto)
# Predicted: [(0, 4, 'Categoria'), (5, 8, 'Marca'), (9, 22, 'Modelo'), (24, 33, 'Tipo'), (35, 44, 'Conectividade'), (46, 51, 'Cor')]
# True: [(0, 4, 'Categoria'), (9, 12, 'Caracteristicas'), (13, 22, 'Modelo'), (24, 33, 'Caracteristicas'), (35, 44, 'Caracteristicas'), (46, 51, 'Cor'), (54, 65, 'Modelo')]
#
#
# Fone De Ouvido Com Fio Pulse 2 Branco Motorola
# (Fone De Ouvido, Com Fio, Pulse, 2, Branco, Motorola)
# Predicted: [(0, 14, 'Categoria'), (15, 22, 'Caracteristicas'), (23, 28, 'Marca'), (29, 30, 'Modelo'), (31, 37, 'Cor'), (38, 46, 'Marca')]
# True: [(0, 14, 'Categoria'), (38, 46, 'Marca')]
#
#
# Fone De Ouvido Silicone Earhook Pulse Rosa/Roxo - PH222
# (Fone, Silicone, Earhook, Pulse, Rosa/Roxo, PH222)
# Predicted: [(0, 4, 'Categoria'), (15, 23, 'Caracteristicas'), (24, 31, 'Caracteristicas'), (32, 37, 'Marca'), (38, 47, 'Cor'), (50, 55, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 23, 'Caracteristicas'), (24, 37, 'Modelo'), (38, 47, 'Cor')]
#
#
# Headset Gamer Corsair HS45 Surround 7.1 Drivers 50mm,Carbono-CA-9011220-NA
# (Headset, Gamer, Corsair, HS45 Surround 7.1, Drivers 50mm)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 21, 'Marca'), (22, 39, 'Modelo'), (40, 52, 'Caracteristicas')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 21, 'Marca'), (22, 26, 'Modelo'), (27, 39, 'Caracteristicas'), (40, 52, 'Tamanho')]
#
#
# Fone de ouvido JBL Endurance Sprint Black
# (Fone de ouvido, JBL, Endurance Sprint, Black)
# Predicted: [(0, 14, 'Categoria'), (15, 18, 'Marca'), (19, 35, 'Modelo'), (36, 41, 'Cor')]
# True: [(0, 14, 'Categoria'), (15, 18, 'Marca'), (19, 35, 'Modelo'), (36, 41, 'Cor')]
#
#
# Fone De Ouvido Multilaser Com Microfone P2 Preto/Azul - PH113
# (Fone De Ouvido, Multilaser, Com Microfone, P2, Preto/Azul, PH113)
# Predicted: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 39, 'Caracteristicas'), (40, 42, 'Conectividade'), (43, 53, 'Cor'), (56, 61, 'Modelo')]
# True: [(26, 39, 'Caracteristicas'), (56, 61, 'Modelo')]
#
#
# Fone de Ouvido Auricular Bluetooth JBL Tune 215BT Pure Bass Hands-Free com Microfone, Preto-JBLT215BTBLK
# (Fone de Ouvido, Auricular, Bluetooth, JBL, Tune 215BT, Pure Bass, Hands-Free, com Microfone)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 34, 'Conectividade'), (35, 38, 'Marca'), (39, 49, 'Modelo'), (50, 59, 'Caracteristicas'), (60, 70, 'Caracteristicas'), (71, 84, 'Caracteristicas')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 34, 'Conectividade'), (35, 38, 'Marca'), (39, 70, 'Caracteristicas'), (71, 84, 'Item adicional')]
#
#
# Caixa de Som Amplificada Amvox ACA 1001, Bluetooth, USB, Karaokê, 1000W, Preto - Bivolt
# (Caixa de Som, Amplificada, Amvox, ACA 1001, Bluetooth, USB, Karaokê, 1000W, Preto, Bivolt)
# Predicted: [(0, 12, 'Categoria'), (13, 24, 'Potência'), (25, 30, 'Marca'), (31, 39, 'Modelo'), (41, 50, 'Conectividade'), (52, 55, 'Conectividade'), (57, 64, 'Caracteristicas'), (66, 71, 'Potência'), (73, 78, 'Cor'), (81, 87, 'Tensão')]
# True: [(0, 12, 'Categoria'), (25, 30, 'Marca'), (31, 39, 'Modelo'), (41, 56, 'Conectividade'), (57, 64, 'Conectividade'), (66, 72, 'Potência'), (73, 78, 'Cor'), (81, 87, 'Marca')]
#
#
# Fones de ouvido JBL Endurance RUN intra-auriculares
# (Fones de ouvido, JBL, Endurance RUN, intra-auriculares)
# Predicted: [(0, 15, 'Categoria'), (16, 19, 'Marca'), (20, 33, 'Modelo'), (34, 51, 'Tipo')]
# True: [(0, 15, 'Categoria'), (16, 19, 'Marca'), (20, 33, 'Modelo'), (34, 51, 'Tipo')]
#
#
# Apple AirPods (3ª geração) com estojo de recarga MagSafe
# (Apple, AirPods (3ª geração, com estojo de recarga, MagSafe)
# Predicted: [(0, 5, 'Marca'), (6, 25, 'Modelo'), (27, 48, 'Caracteristicas'), (49, 56, 'Modelo')]
# True: [(0, 5, 'Marca'), (6, 26, 'Modelo'), (27, 48, 'Caracteristicas'), (49, 56, 'Caracteristicas')]
#
#
# Pulse Bluetooth Speaker Wave II Camuflada - SP374
# (Pulse, Bluetooth, Speaker, Wave II, Camuflada, SP374)
# Predicted: [(0, 5, 'Marca'), (6, 15, 'Conectividade'), (16, 23, 'Categoria'), (24, 31, 'Modelo'), (32, 41, 'Cor'), (44, 49, 'Modelo')]
# True: [(0, 5, 'Marca'), (6, 15, 'Conectividade'), (16, 23, 'Categoria'), (24, 31, 'Modelo'), (32, 41, 'Cor')]
#
#
# Fone de Ouvido Intra-Auricular Bluetooth JBL Tune 125BT, Branco-JBLT125BTWHT
# (Fone de Ouvido, Intra-Auricular, Bluetooth, JBL, Tune 125BT)
# Predicted: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
# True: [(0, 14, 'Categoria'), (31, 40, 'Conectividade'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
#
#
# Fone De Ouvido Headset Com Microfone  Preto Bright 0010
# (Fone, Headset, Com Microfone, Preto, Bright)
# Predicted: [(0, 4, 'Categoria'), (15, 22, 'Marca'), (23, 36, 'Caracteristicas'), (38, 43, 'Cor'), (44, 50, 'Marca')]
# True: [(0, 14, 'Categoria'), (15, 22, 'Tipo'), (23, 36, 'Item adicional'), (38, 43, 'Cor'), (44, 55, 'Modelo')]
#
#
# Fone de Ouvido Bluetooth In-Ear JBL Tune 225TWS, Preto - JBLT225TWSBLK
# (Fone de Ouvido, Bluetooth, In-Ear, JBL, Tune 225TWS, Preto, JBLT225TWSBLK)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 31, 'Tipo'), (32, 35, 'Marca'), (36, 47, 'Modelo'), (49, 54, 'Cor'), (57, 70, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 31, 'Tipo'), (32, 35, 'Marca'), (36, 47, 'Modelo'), (49, 54, 'Cor'), (57, 70, 'Modelo')]
#
#
# Fone de Ouvido Auricular JBL Bluetooth 300 Wave TWS, Branco - JBLW300TWSWHT
# (Fone de Ouvido, Auricular, JBL, Bluetooth, Wave TWS, Branco, JBLW300TWSWHT)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (43, 51, 'Modelo'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (39, 47, 'Modelo'), (48, 51, 'Conectividade'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
#
#
# Pulse Bluetooth Speaker Xplode II - SP386
# (Pulse, Bluetooth, Speaker, Xplode II, SP386)
# Predicted: [(0, 5, 'Marca'), (6, 15, 'Conectividade'), (16, 23, 'Categoria'), (24, 33, 'Modelo'), (36, 41, 'Modelo')]
# True: [(0, 5, 'Marca'), (6, 15, 'Conectividade'), (16, 23, 'Categoria'), (24, 33, 'Modelo'), (36, 41, 'Modelo')]
#
#
# Caixa de Som portátil JBL Partybox 100 Bluetooth USB
# (Caixa de Som, portátil, JBL, Partybox 100, Bluetooth, USB)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 38, 'Modelo'), (39, 48, 'Conectividade'), (49, 52, 'Conectividade')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 38, 'Modelo'), (39, 48, 'Conectividade'), (49, 52, 'Conectividade')]
#
#
# Headset Gamer HyperX Cloud Stinger Core PC- HX-HSCSC2-BK/WW
# (Headset, Gamer, HyperX, Cloud Stinger Core PC-, HX-HSCSC2-BK/WW)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (21, 43, 'Modelo'), (44, 59, 'Modelo')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (21, 43, 'Modelo'), (44, 59, 'Modelo')]
#
#
# Projetor Benq MX550 XGA 3600 Lumens HDMI - 9H.JHY77.13L
# (Projetor, Benq, MX550, XGA, HDMI, 9H.JHY77.13L)
# Predicted: [(0, 8, 'Categoria'), (9, 13, 'Marca'), (14, 19, 'Modelo'), (20, 23, 'Conectividade'), (36, 40, 'Conectividade'), (43, 55, 'Modelo')]
# True: [(0, 8, 'Categoria'), (9, 13, 'Marca'), (14, 23, 'Modelo'), (24, 35, 'Potência'), (36, 40, 'Conectividade')]
#
#
# Caixa de Som JBL PartyBox 310 Bluetooth Portátil - Amplificada USB com Tweeter
# (Caixa de Som, JBL, PartyBox 310, Bluetooth, Portátil, Amplificada, USB, com Tweeter)
# Predicted: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 29, 'Modelo'), (30, 39, 'Conectividade'), (40, 48, 'Tipo'), (51, 62, 'Potência'), (63, 66, 'Conectividade'), (67, 78, 'Caracteristicas')]
# True: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 29, 'Modelo'), (30, 39, 'Conectividade'), (40, 48, 'Tipo'), (51, 62, 'Potência'), (63, 66, 'Conectividade'), (67, 78, 'Caracteristicas')]
#
#
# Caixa De Som Bluetooth Wonderboom Azul Logitech
# (Caixa De Som, Bluetooth, Wonderboom Azul, Logitech)
# Predicted: [(0, 12, 'Categoria'), (13, 22, 'Conectividade'), (23, 38, 'Modelo'), (39, 47, 'Marca')]
# True: [(0, 12, 'Categoria'), (13, 22, 'Conectividade'), (23, 33, 'Modelo'), (34, 38, 'Cor'), (39, 47, 'Marca')]
#
#
# Earphone TWS Pulse Drop PRETO Pulse Sound - PH345
# (Earphone, TWS, Pulse, PRETO, Pulse, PH345)
# Predicted: [(0, 8, 'Categoria'), (9, 12, 'Conectividade'), (13, 18, 'Marca'), (24, 29, 'Cor'), (30, 35, 'Marca'), (44, 49, 'Modelo')]
# True: [(0, 8, 'Categoria'), (9, 12, 'Conectividade'), (13, 18, 'Marca'), (19, 23, 'Modelo'), (24, 29, 'Cor'), (30, 35, 'Marca'), (36, 49, 'Modelo')]
#
#
# Mini System Pulse Bluetooth 2350W RMS DVD USB - SP700
# (Mini System, Pulse, Bluetooth, 2350W RMS, USB, SP700)
# Predicted: [(0, 11, 'Categoria'), (12, 17, 'Marca'), (18, 27, 'Conectividade'), (28, 37, 'Potência'), (42, 45, 'Conectividade'), (48, 53, 'Modelo')]
# True: [(0, 11, 'Categoria'), (12, 17, 'Marca'), (18, 27, 'Conectividade'), (28, 37, 'Potência'), (48, 53, 'Modelo')]
#
#
# Caixa de Som Portátil JBL GO 3 Bluetooth 5.1 À Prova D'água e Poeira IP67 Preto
# (Caixa de Som, Portátil, JBL, GO 3, Bluetooth 5.1, À Prova D'água e Poeira, IP67, Preto)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 30, 'Modelo'), (31, 44, 'Conectividade'), (45, 68, 'Caracteristicas'), (69, 73, 'Caracteristicas'), (74, 79, 'Cor')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 30, 'Modelo'), (31, 44, 'Conectividade'), (45, 73, 'Caracteristicas'), (74, 79, 'Cor')]
#
#
# Fone de Ouvido Auricular Bluetooth JBL Tune 215BT Pure Bass Hands-Free com Microfone, Preto-JBLT215BTBLK
# (Fone de Ouvido, Auricular, Bluetooth, JBL, Tune 215BT, Pure Bass, Hands-Free, com Microfone)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 34, 'Conectividade'), (35, 38, 'Marca'), (39, 49, 'Modelo'), (50, 59, 'Caracteristicas'), (60, 70, 'Caracteristicas'), (71, 84, 'Caracteristicas')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 34, 'Conectividade'), (35, 38, 'Marca'), (71, 84, 'Caracteristicas')]
#
#
# Fone de Ouvido Auricular Bluetooth JBL Tune 215BT Pure Bass Hands-Free com Microfone, Preto-JBLT215BTBLK
# (Fone de Ouvido, Auricular, Bluetooth, JBL, Tune 215BT, Pure Bass, Hands-Free, com Microfone)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 34, 'Conectividade'), (35, 38, 'Marca'), (39, 49, 'Modelo'), (50, 59, 'Caracteristicas'), (60, 70, 'Caracteristicas'), (71, 84, 'Caracteristicas')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 34, 'Conectividade'), (35, 38, 'Marca'), (39, 49, 'Modelo'), (50, 59, 'Caracteristicas'), (60, 70, 'Caracteristicas'), (71, 84, 'Caracteristicas')]
#
#
# Kit Tablet Samsung Galaxy S7 FE 4G 128GB Prata com S Pen + Fone de Ouvido Bluetooth Samsung Galaxy Buds Live Preto
# (Kit Tablet, Samsung, Galaxy S7 FE 4G 128GB, Prata, com S Pen +, Fone de Ouvido, Bluetooth, Samsung, Galaxy Buds Live, Preto)
# Predicted: [(0, 10, 'Categoria'), (11, 18, 'Marca'), (19, 40, 'Modelo'), (41, 46, 'Cor'), (47, 58, 'Caracteristicas'), (59, 73, 'Categoria'), (74, 83, 'Conectividade'), (84, 91, 'Marca'), (92, 108, 'Modelo'), (109, 114, 'Cor')]
# True: [(11, 18, 'Marca'), (41, 46, 'Cor'), (74, 83, 'Conectividade'), (84, 91, 'Marca'), (92, 108, 'Modelo'), (109, 114, 'Cor')]
#
#
# Headset Gamer GT Attack 7.1 Canais com LED para Desktop | GT Gamer
# (Headset, Gamer, GT, Attack, 7.1 Canais, LED para Desktop |, GT)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 16, 'Marca'), (17, 23, 'Marca'), (24, 34, 'Caracteristicas'), (39, 57, 'Caracteristicas'), (58, 60, 'Marca')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 16, 'Marca'), (17, 34, 'Modelo'), (39, 57, 'Caracteristicas'), (58, 60, 'Marca'), (61, 66, 'Caracteristicas')]
#
#
# Headset Office GT Basic com Cabo de 1.8m | GT
# (Headset, Office GT Basic, com Cabo de 1.8m, GT)
# Predicted: [(0, 7, 'Categoria'), (8, 23, 'Modelo'), (24, 40, 'Caracteristicas'), (43, 45, 'Marca')]
# True: [(0, 7, 'Categoria'), (8, 23, 'Modelo'), (24, 40, 'Caracteristicas')]
#
#
# Fone de Ouvido Intra-Auricular Bluetooth JBL Tune 125BT, Branco-JBLT125BTWHT
# (Fone de Ouvido, Intra-Auricular, Bluetooth, JBL, Tune 125BT)
# Predicted: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
#
#
# Fone De Ouvido Multilaser Headset Light P2 Preto - PH063
# (Fone, Multilaser, Headset, Light, P2, Preto, PH063)
# Predicted: [(0, 4, 'Categoria'), (15, 25, 'Marca'), (26, 33, 'Tipo'), (34, 39, 'Modelo'), (40, 42, 'Conectividade'), (43, 48, 'Cor'), (51, 56, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 33, 'Categoria'), (40, 42, 'Conectividade'), (43, 48, 'Cor'), (51, 56, 'Modelo')]
#
#
# Earhook Sport Stereo Audio - PH205
# (Earhook, Sport, Stereo, Audio, PH205)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Marca'), (14, 20, 'Caracteristicas'), (21, 26, 'Caracteristicas'), (29, 34, 'Modelo')]
# True: [(0, 26, 'Modelo'), (29, 34, 'Modelo')]
#
#
# Fone Auricular Goldentec GT Vibe Preto (GT10P)
# (Fone, Auricular, Goldentec, GT Vibe, Preto)
# Predicted: [(0, 4, 'Categoria'), (5, 14, 'Tipo'), (15, 24, 'Marca'), (25, 32, 'Modelo'), (33, 38, 'Cor')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Marca'), (25, 32, 'Modelo'), (33, 38, 'Cor')]
#
#
# Fone De Ouvido Multikids Estéreo P2 Ajustável Frozen - PH127
# (Fone De Ouvido, Multikids Estéreo, P2, Ajustável, Frozen - PH127)
# Predicted: [(0, 14, 'Categoria'), (15, 32, 'Modelo'), (33, 35, 'Conectividade'), (36, 45, 'Tipo'), (46, 60, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Marca'), (25, 32, 'Caracteristicas'), (33, 35, 'Conectividade'), (36, 45, 'Caracteristicas'), (46, 52, 'Modelo'), (55, 60, 'Modelo')]
#
#
# Headset Gamer Sony Pulse 3D para PS5
# (Headset, Gamer, Pulse, 3D para, PS5)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (19, 24, 'Marca'), (25, 32, 'Potência'), (33, 36, 'Conectividade')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 18, 'Modelo'), (19, 24, 'Marca'), (33, 36, 'Conectividade')]
#
#
# Fone de Ouvido Auricular JBL TWS, Tune Flex, Preto - JBLTFLEXBLK
# (Fone de Ouvido, Auricular, JBL, TWS, Tune Flex, Preto, JBLTFLEXBLK)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 32, 'Conectividade'), (34, 43, 'Modelo'), (45, 50, 'Cor'), (53, 64, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 32, 'Conectividade'), (34, 43, 'Modelo'), (45, 50, 'Cor')]
#
#
# Caixa de Som Cubo Speaker 3W Rosa Multilaser - SP307
# (Caixa de Som, Cubo, Speaker, 3W, Rosa, Multilaser, SP307)
# Predicted: [(0, 12, 'Categoria'), (13, 17, 'Modelo'), (18, 25, 'Categoria'), (26, 28, 'Modelo'), (29, 33, 'Cor'), (34, 44, 'Marca'), (47, 52, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 25, 'Modelo'), (26, 28, 'Potência'), (29, 33, 'Cor'), (34, 44, 'Marca')]
#
#
# Fone de Ouvido Bluetooth T205BT Preto JBL
# (Fone de Ouvido, Bluetooth, T205BT, Preto, JBL)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 31, 'Modelo'), (32, 37, 'Cor'), (38, 41, 'Marca')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 31, 'Modelo'), (32, 37, 'Cor'), (38, 41, 'Marca')]
#
#
# Caixa Acústica Philco PCX16000 - Bivolt
# (Caixa Acústica Philco PCX16000, Bivolt)
# Predicted: [(0, 30, 'Categoria'), (33, 39, 'Tensão')]
# True: [(0, 14, 'Categoria'), (15, 21, 'Marca'), (22, 30, 'Modelo'), (33, 39, 'Tensão')]
#
#
# Torre Double 10 Pol. 1700W - SP501
# (Torre, Double, 10 Pol., 1700W, SP501)
# Predicted: [(0, 5, 'Categoria'), (6, 12, 'Caracteristicas'), (13, 20, 'Potência'), (21, 26, 'Potência'), (29, 34, 'Modelo')]
# True: [(0, 5, 'Categoria'), (6, 12, 'Modelo'), (13, 19, 'Tamanho'), (21, 26, 'Potência'), (29, 34, 'Modelo')]
#
#
# Caixa de Som Mini Bluetooth Speaker 5W Azul Multilaser - SP312
# (Caixa de Som, Mini, Bluetooth, Speaker, 5W, Azul, Multilaser, SP312)
# Predicted: [(0, 12, 'Categoria'), (13, 17, 'Modelo'), (18, 27, 'Conectividade'), (28, 35, 'Categoria'), (36, 38, 'Potência'), (39, 43, 'Cor'), (44, 54, 'Marca'), (57, 62, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 17, 'Modelo'), (18, 27, 'Conectividade'), (28, 35, 'Categoria'), (36, 38, 'Modelo'), (39, 43, 'Cor'), (44, 54, 'Marca')]
#
#
# Boombox / Som Portátil Philco PB140, MP3, MP4, FM, Branco - Bivolt
# (Boombox / Som, Portátil, Philco PB140, MP3, MP4, Branco, Bivolt)
# Predicted: [(0, 13, 'Categoria'), (14, 22, 'Tipo'), (23, 35, 'Modelo'), (37, 40, 'Conectividade'), (42, 45, 'Modelo'), (51, 57, 'Cor'), (60, 66, 'Tensão')]
# True: [(23, 29, 'Marca'), (30, 50, 'Conectividade'), (51, 57, 'Cor'), (60, 66, 'Marca')]
#
#
# Suporte para Headset Gamer Trust GXT 265 Cintar RGB com 2 portas USB - T23674
# (Suporte para, Headset, Gamer, Trust, 265 Cintar RGB, USB, T23674)
# Predicted: [(0, 12, 'Categoria'), (13, 20, 'Categoria'), (21, 26, 'Caracteristicas'), (27, 32, 'Marca'), (37, 51, 'Caracteristicas'), (65, 68, 'Conectividade'), (71, 77, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 20, 'Categoria'), (21, 26, 'Caracteristicas'), (27, 32, 'Marca'), (33, 51, 'Modelo'), (65, 68, 'Conectividade'), (71, 77, 'Modelo')]
#
#
# Caixa de Som Portátil JBL Clip 4 Bluetooth 5W À Prova D'água e Poeira IP67 Vermelho
# (Caixa de Som, Portátil, JBL, Clip 4, Bluetooth, 5W, À Prova D'água e Poeira, IP67, Vermelho)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 32, 'Modelo'), (33, 42, 'Conectividade'), (43, 45, 'Potência'), (46, 69, 'Caracteristicas'), (70, 74, 'Caracteristicas'), (75, 83, 'Cor')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 32, 'Modelo'), (33, 42, 'Conectividade'), (43, 45, 'Potência'), (75, 83, 'Cor')]
#
#
# Headphone Bluetooth 5.0 Pulse Head Beats Preto Bateria 20h - PH339
# (Headphone, Bluetooth, Pulse, Head Beats, Preto, Bateria 20h, PH339)
# Predicted: [(0, 9, 'Categoria'), (10, 19, 'Conectividade'), (24, 29, 'Marca'), (30, 40, 'Modelo'), (41, 46, 'Cor'), (47, 58, 'Caracteristicas'), (61, 66, 'Modelo')]
# True: [(0, 9, 'Categoria'), (10, 23, 'Conectividade'), (24, 29, 'Marca'), (30, 40, 'Modelo'), (41, 46, 'Cor'), (47, 58, 'Caracteristicas'), (61, 66, 'Modelo')]
#
#
# Caixa de Som Portátil Bluetooth JBL Xtreme 2 Black
# (Caixa de Som, Portátil, Bluetooth, JBL, Xtreme 2, Black)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 31, 'Conectividade'), (32, 35, 'Marca'), (36, 44, 'Modelo'), (45, 50, 'Cor')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 31, 'Conectividade'), (32, 35, 'Marca'), (36, 44, 'Modelo'), (45, 50, 'Cor')]
#
#
# Caixa De Som Boombox 80W Rms Usb Sd Fm Aux Bivolt - SP163
# (Caixa De Som, Boombox, 80W, Usb, Fm, Bivolt, SP163)
# Predicted: [(0, 12, 'Categoria'), (13, 20, 'Marca'), (21, 24, 'Potência'), (29, 32, 'Conectividade'), (36, 38, 'Conectividade'), (43, 49, 'Tensão'), (52, 57, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 20, 'Marca'), (21, 28, 'Potência'), (29, 35, 'Conectividade'), (36, 49, 'Modelo'), (52, 57, 'Modelo')]
#
#
# Fone de Ouvido Intra-Auricular Bluetooth JBL Tune 125BT, Branco-JBLT125BTWHT
# (Fone de Ouvido, Intra-Auricular, Bluetooth, JBL, Tune 125BT)
# Predicted: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
#
#
# Fone de Ouvido Auricular JBL Wave 200TWS, Azul - JBLW200TWSBLU
# (Fone de Ouvido, Auricular, JBL, Wave 200TWS, Azul, JBLW200TWSBLU)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 40, 'Modelo'), (42, 46, 'Cor'), (49, 62, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 40, 'Modelo'), (42, 46, 'Cor'), (49, 62, 'Modelo')]
#
#
# Fone De Ouvido Multilaser Plug P2 Branco - PH017
# (Fone De Ouvido, Multilaser, Plug P2, Branco, PH017)
# Predicted: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 33, 'Modelo'), (34, 40, 'Cor'), (43, 48, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 33, 'Modelo'), (34, 40, 'Cor'), (43, 48, 'Modelo')]
#
#
# Caixa De Som Bluetooth Mini Speaker 3W CM510 Huawei
# (Caixa De Som, Bluetooth, Mini, Speaker, 3W CM510, Huawei)
# Predicted: [(0, 12, 'Categoria'), (13, 22, 'Conectividade'), (23, 27, 'Modelo'), (28, 35, 'Categoria'), (36, 44, 'Potência'), (45, 51, 'Marca')]
# True: [(0, 12, 'Categoria'), (13, 22, 'Conectividade'), (23, 35, 'Modelo'), (36, 38, 'Potência'), (39, 44, 'Modelo'), (45, 51, 'Marca')]
#
#
# Caixa de Som JBL GO Essential Vermelha - JBLGOESRED
# (Caixa de Som, JBL, Vermelha, JBLGOESRED)
# Predicted: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (30, 38, 'Cor'), (41, 51, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 29, 'Modelo'), (30, 38, 'Cor'), (41, 51, 'Modelo')]
#
#
# Fone de Ouvido Bluetooth JBL Tune 510BT Preto JBLT510BTBLK
# (Fone de Ouvido, Bluetooth, JBL, Tune 510BT, Preto, JBLT510BTBLK)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 28, 'Marca'), (29, 39, 'Modelo'), (40, 45, 'Cor'), (46, 58, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 28, 'Marca'), (29, 39, 'Modelo'), (40, 45, 'Cor'), (46, 58, 'Modelo')]
#
#
# Fone de Ouvido Auricular JBL T215 TWS , Preto
# (Fone de Ouvido, Auricular, JBL, T215, TWS, Preto)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 33, 'Modelo'), (34, 37, 'Conectividade'), (40, 45, 'Cor')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (34, 37, 'Conectividade'), (40, 45, 'Cor')]
#
#
# Headset Office GT Professional com Cabo de 1.8m | GT
# (Headset, Office GT Professional, com Cabo de 1.8m, GT)
# Predicted: [(0, 7, 'Categoria'), (8, 30, 'Modelo'), (31, 47, 'Caracteristicas'), (50, 52, 'Marca')]
# True: [(0, 7, 'Categoria'), (8, 30, 'Modelo'), (35, 47, 'Tamanho')]
#
#
# Caixa de Som Acústica Multilaser SUNNY 12 Pol 400W BT/AUX/SD/USB/FM/LED – SP340
# (Caixa de Som, Acústica, Multilaser, SUNNY, 400W, BT/, AUX, USB, LED, SP340)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Caracteristicas'), (22, 32, 'Marca'), (33, 38, 'Modelo'), (46, 50, 'Potência'), (51, 54, 'Conectividade'), (54, 57, 'Conectividade'), (61, 64, 'Conectividade'), (68, 71, 'Caracteristicas'), (74, 79, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Caracteristicas'), (22, 32, 'Marca'), (33, 45, 'Modelo'), (46, 50, 'Potência'), (51, 71, 'Conectividade'), (74, 79, 'Modelo')]
#
#
# Caixa de Som portátil JBL Partybox 100 Bluetooth USB
# (Caixa de Som, portátil, JBL, Partybox 100, Bluetooth, USB)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 38, 'Modelo'), (39, 48, 'Conectividade'), (49, 52, 'Conectividade')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 38, 'Modelo'), (39, 48, 'Conectividade'), (49, 52, 'Conectividade')]
#
#
# Caixa de Som Portátil JBL GO 3 Bluetooth 5.1 À Prova D'água e Poeira IP67 Preto
# (Caixa de Som, Portátil, JBL, GO 3, Bluetooth 5.1, À Prova D'água e Poeira, IP67, Preto)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 30, 'Modelo'), (31, 44, 'Conectividade'), (45, 68, 'Caracteristicas'), (69, 73, 'Caracteristicas'), (74, 79, 'Cor')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 30, 'Modelo'), (31, 44, 'Conectividade'), (45, 68, 'Caracteristicas'), (69, 73, 'Caracteristicas'), (74, 79, 'Cor')]
#
#
# Fone De Ouvido Auricular Fitness Verde Multilaser - PH165
# (Fone, Auricular, Fitness, Verde, Multilaser, PH165)
# Predicted: [(0, 4, 'Categoria'), (15, 24, 'Tipo'), (25, 32, 'Modelo'), (33, 38, 'Cor'), (39, 49, 'Marca'), (52, 57, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 32, 'Modelo'), (33, 38, 'Cor'), (39, 49, 'Marca'), (52, 57, 'Modelo')]
#
#
#                  precision    recall  f1-score   support
#
# Caracteristicas       0.52      0.70      0.60        53
#       Categoria       0.83      0.86      0.84       101
#   Conectividade       0.69      0.79      0.74        81
#             Cor       0.93      0.93      0.93        45
#  Item adicional       1.00      0.20      0.33         5
#           Marca       0.83      0.90      0.86        92
#          Modelo       0.63      0.66      0.65       128
#               O       0.00      0.00      0.00       150
#        Potência       0.57      0.64      0.60        25
#         Tamanho       0.00      0.00      0.00         6
#          Tensão       0.40      1.00      0.57         2
#            Tipo       0.82      0.97      0.89        32
#
#        accuracy                           0.62       720
#       macro avg       0.60      0.64      0.58       720
#    weighted avg       0.57      0.62      0.59       720
# c:\Users\Luca\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Luca\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Luca\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Convert test data to spaCy Examples
examples = [Example.from_dict(nlp.make_doc(text), annotations) for text, annotations in test_data_spacy]

# Evaluate the model using SpaCy's built-in evaluate function
results = nlp.evaluate(examples)

# Print the evaluation results
print(f"Precision: {results['ents_p']:.4f}")
print(f"Recall: {results['ents_r']:.4f}")
print(f"F1-score: {results['ents_f']:.4f}")
print(f"Entity-wise results: {results['ents_per_type']}")
# Out:
# Precision: 0.7214
# Recall: 0.7860
# F1-score: 0.7523
# Entity-wise results: {'Categoria': {'p': 0.8285714285714286, 'r': 0.8613861386138614, 'f': 0.8446601941747574}, 'Conectividade': {'p': 0.6881720430107527, 'r': 0.7901234567901234, 'f': 0.735632183908046}, 'Marca': {'p': 0.83, 'r': 0.9021739130434783, 'f': 0.8645833333333334}, 'Modelo': {'p': 0.6296296296296297, 'r': 0.6640625, 'f': 0.6463878326996197}, 'Cor': {'p': 0.9333333333333333, 'r': 0.9333333333333333, 'f': 0.9333333333333333}, 'Caracteristicas': {'p': 0.5211267605633803, 'r': 0.6981132075471698, 'f': 0.5967741935483871}, 'Tipo': {'p': 0.8157894736842105, 'r': 0.96875, 'f': 0.8857142857142857}, 'Potência': {'p': 0.5714285714285714, 'r': 0.64, 'f': 0.6037735849056605}, 'Tamanho': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'Item adicional': {'p': 1.0, 'r': 0.2, 'f': 0.33333333333333337}, 'Tensão': {'p': 0.4, 'r': 1.0, 'f': 0.5714285714285715}}

# %%
# Example text to test the model
doc = nlp("Fone JBL TWS Wave Buds, Auricular, Bluetooth, Preto - JBLWBUDSBLK")

# Print the entities recognized by the model
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Fone 0 4 Categoria
# JBL 5 8 Marca
# TWS Wave Buds 9 22 Modelo
# Auricular 24 33 Tipo
# Bluetooth 35 44 Conectividade
# Preto 46 51 Cor
