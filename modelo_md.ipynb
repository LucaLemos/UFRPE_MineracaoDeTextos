# %%
import spacy
import random
import jsonlines
from spacy.training import Example, offsets_to_biluo_tags
from spacy.tokens import DocBin
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
import os

# %%
# Load the SpaCy model
nlp = spacy.load("pt_core_news_md")

# %%
data = []
with jsonlines.open('dataset.jsonl', 'r') as reader:
    for line in reader:
        data.append(line)

# %%
# Shuffle the dataset to randomize the order
random.shuffle(data)

# %%
# Function to adjust entity spans according to SpaCy's token boundaries
def adjust_entity_spans(doc, entities):
    adjusted_entities = []
    for start, end, label in entities:
        span = doc.char_span(start, end, label=label)
        if span is not None:
            adjusted_entities.append((span.start_char, span.end_char, label))
    return adjusted_entities

# %%
# Convert the dataset to SpaCy format and adjust entity spans
def convert_data_for_spacy(data, nlp):
    spacy_format = []
    for item in data:
        text = item['text']
        doc = nlp.make_doc(text)
        entities = adjust_entity_spans(doc, item['label'])
        spacy_format.append((text, {"entities": entities}))
    return spacy_format

# %%
# Split the data into training and test sets
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# Convert and adjust the training and test data
training_data = convert_data_for_spacy(train_data, nlp)
test_data_spacy = convert_data_for_spacy(test_data, nlp)

# %%
# Add the NER pipeline if not already present
if 'ner' not in nlp.pipe_names:
    ner = nlp.add_pipe('ner')
else:
    ner = nlp.get_pipe('ner')

# Add custom labels to the NER component
for _, annotations in training_data:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

# %%
# Disable other pipeline components during training
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']

# %%
# Fine-tune the model
with nlp.disable_pipes(*unaffected_pipes):
    optimizer = nlp.resume_training()
    for iteration in range(20):  # You can change the number of iterations
        random.shuffle(training_data)
        losses = {}
        for text, annotations in training_data:
            example = Example.from_dict(nlp.make_doc(text), annotations)
            nlp.update([example], drop=0.5, losses=losses)
        print(f"Iteration {iteration + 1}, Losses: {losses}")
# Out:
# Iteration 1, Losses: {'ner': 2575.7900014288425}
# Iteration 2, Losses: {'ner': 1698.62290668682}
# Iteration 3, Losses: {'ner': 1549.0265327694733}
# Iteration 4, Losses: {'ner': 1400.308129452041}
# Iteration 5, Losses: {'ner': 1276.1925675071354}
# Iteration 6, Losses: {'ner': 1222.2812704422956}
# Iteration 7, Losses: {'ner': 1130.0735562070752}
# Iteration 8, Losses: {'ner': 1077.2548294683036}
# Iteration 9, Losses: {'ner': 1065.8895227458945}
# Iteration 10, Losses: {'ner': 1030.9961921576416}
# Iteration 11, Losses: {'ner': 989.7392447534589}
# Iteration 12, Losses: {'ner': 956.0553419825991}
# Iteration 13, Losses: {'ner': 963.5632797292383}
# Iteration 14, Losses: {'ner': 888.8537368418592}
# Iteration 15, Losses: {'ner': 907.4875525059841}
# Iteration 16, Losses: {'ner': 856.424840624886}
# Iteration 17, Losses: {'ner': 864.6060333757406}
# Iteration 18, Losses: {'ner': 800.9673997441838}
# Iteration 19, Losses: {'ner': 776.9984568839478}
# Iteration 20, Losses: {'ner': 787.432477061417}

# %%
# Save the fine-tuned model
output_dir = "3VA/model_md"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
nlp.to_disk(output_dir)
print(f"Model saved to {output_dir}")
# Out:
# Model saved to 3VA/model_md

# %%
# Test the fine-tuned model
nlp = spacy.load(output_dir)

# %%
# Initialize lists for true and predicted labels
true_labels = []
pred_labels = []

for text, annotations in test_data_spacy:
    doc = nlp(text)
    pred_entities = [(ent.start_char, ent.end_char, ent.label_) for ent in doc.ents]
    true_entities = annotations["entities"]

    # Print entities for debugging
    print(text)
    print(doc.ents)
    print("Predicted:", pred_entities)
    print("True:", true_entities)
    print("\n")

    # Create a dictionary to store the predicted and true labels with their spans
    pred_dict = {(start, end): label for start, end, label in pred_entities}
    true_dict = {(start, end): label for start, end, label in true_entities}

    # Union of all spans (keys) from both true and predicted dictionaries
    all_spans = set(pred_dict.keys()).union(set(true_dict.keys()))

    # Compare the labels based on spans
    for span in all_spans:
        true_labels.append(true_dict.get(span, "O"))  # "O" represents no entity in the true labels
        pred_labels.append(pred_dict.get(span, "O"))  # "O" represents no entity in the predicted labels

# Calculate precision, recall, and F1-score
print(classification_report(true_labels, pred_labels))
# Out:
# Soundbar 2.1 Canais Bluetooth 180W RMS com Subwoofer e USB | GT
# (Soundbar, Bluetooth, RMS, com Subwoofer, USB, GT)
# Predicted: [(0, 8, 'Categoria'), (20, 29, 'Conectividade'), (35, 38, 'Caracteristicas'), (39, 52, 'Item adicional'), (55, 58, 'Conectividade'), (61, 63, 'Marca')]
# True: [(9, 19, 'Modelo'), (30, 38, 'Potência'), (39, 52, 'Item adicional'), (61, 63, 'Marca')]
#
#
# Fone de Ouvido JBL Wireless Bluetooth T205 BT, Rose Gold
# (Fone de Ouvido, JBL, Wireless, Bluetooth, T205 BT, Rose Gold)
# Predicted: [(0, 14, 'Categoria'), (15, 18, 'Marca'), (19, 27, 'Conectividade'), (28, 37, 'Conectividade'), (38, 45, 'Modelo'), (47, 56, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 18, 'Marca'), (19, 27, 'Tipo'), (28, 37, 'Conectividade'), (38, 45, 'Modelo'), (47, 56, 'Cor')]
#
#
# Vitrola Retro Bluetooth Pulse Morrison - SP613
# (Vitrola, Retro, Bluetooth, Pulse, Morrison, SP613)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 23, 'Conectividade'), (24, 29, 'Marca'), (30, 38, 'Marca'), (41, 46, 'Modelo')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 23, 'Conectividade'), (24, 29, 'Marca'), (30, 38, 'Modelo'), (41, 46, 'Modelo')]
#
#
# Caixa De Som Pulse Mini Bluetooth/Sd/P2 10W Rms Preta E Amarela - SP238
# (Caixa De Som, Pulse, Mini, Bluetooth/Sd, 10W Rms, Preta E Amarela, SP238)
# Predicted: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 23, 'Modelo'), (24, 36, 'Conectividade'), (40, 47, 'Potência'), (48, 63, 'Cor'), (66, 71, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 23, 'Modelo'), (24, 39, 'Conectividade'), (40, 47, 'Potência'), (48, 53, 'Cor'), (56, 63, 'Cor')]
#
#
# Pulse Bluetooth Speaker Wave II Azul - SP375
# (Pulse, Bluetooth, Speaker, Wave II, Azul, SP375)
# Predicted: [(0, 5, 'Marca'), (6, 15, 'Conectividade'), (16, 23, 'Categoria'), (24, 31, 'Modelo'), (32, 36, 'Cor'), (39, 44, 'Modelo')]
# True: [(0, 5, 'Marca'), (6, 15, 'Conectividade'), (16, 23, 'Categoria'), (24, 31, 'Modelo'), (32, 36, 'Cor')]
#
#
# Fone De Ouvido Multilaser Headphone Vibe Design Retro P2 Branco - PH054
# (De Ouvido, Multilaser, Headphone, Vibe, Design Retro, P2, Branco, PH054)
# Predicted: [(5, 14, 'Tamanho'), (15, 25, 'Marca'), (26, 35, 'Tipo'), (36, 40, 'Modelo'), (41, 53, 'Caracteristicas'), (54, 56, 'Conectividade'), (57, 63, 'Cor'), (66, 71, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 35, 'Tipo'), (36, 40, 'Modelo'), (41, 53, 'Caracteristicas'), (54, 56, 'Conectividade'), (57, 63, 'Cor'), (66, 71, 'Modelo')]
#
#
# Headphone Premium Wired Large Branco - PH238
# (Headphone, Premium, Wired, Large, Branco, PH238)
# Predicted: [(0, 9, 'Categoria'), (10, 17, 'Modelo'), (18, 23, 'Conectividade'), (24, 29, 'Modelo'), (30, 36, 'Cor'), (39, 44, 'Modelo')]
# True: [(0, 9, 'Categoria'), (10, 17, 'Modelo'), (18, 23, 'Conectividade'), (24, 29, 'Modelo'), (30, 36, 'Cor'), (39, 44, 'Modelo')]
#
#
# Headset Sem Fio Gamer HyperX Cloud Stinger Core 7.1 -HHSS1C-BA-BK/G
# (Headset, Sem Fio, Gamer, HyperX, Cloud Stinger Core 7.1, HHSS1C-BA-BK/G)
# Predicted: [(0, 7, 'Categoria'), (8, 15, 'Tipo'), (16, 21, 'Caracteristicas'), (22, 28, 'Marca'), (29, 51, 'Modelo'), (53, 67, 'Modelo')]
# True: [(0, 7, 'Categoria'), (8, 15, 'Modelo'), (16, 21, 'Caracteristicas'), (22, 28, 'Marca'), (29, 51, 'Modelo')]
#
#
# Fone De Ouvido Bluetooth Awei A900bl
# (De Ouvido, Bluetooth, Awei)
# Predicted: [(5, 14, 'Tamanho'), (15, 24, 'Conectividade'), (25, 29, 'Marca')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 29, 'Marca'), (30, 36, 'Modelo')]
#
#
# Headset Gamer Trust GXT 430 Ironn 50mm PS4 / PS5 / XBOX Series / SWITCH / PC -T23209
# (Headset, Gamer, Trust, GXT 430 Ironn 50mm, PS4, PS5, XBOX, SWITCH)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 19, 'Marca'), (20, 38, 'Modelo'), (39, 42, 'Conectividade'), (45, 48, 'Conectividade'), (51, 55, 'Conectividade'), (65, 71, 'Conectividade')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 19, 'Marca'), (20, 33, 'Modelo'), (34, 38, 'Tamanho'), (39, 42, 'Conectividade'), (45, 48, 'Conectividade'), (51, 62, 'Conectividade'), (65, 71, 'Conectividade'), (74, 76, 'Conectividade')]
#
#
# Headset Gamer Corsair HS35 Stereo PC/PS4/Xbox Drivers 50mm, Verde-CA-9011197-NA
# (Headset, Gamer, Corsair, HS35, Stereo, PC/PS4/, Xbox, Drivers 50mm)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 21, 'Marca'), (22, 26, 'Modelo'), (27, 33, 'Caracteristicas'), (34, 41, 'Caracteristicas'), (41, 45, 'Conectividade'), (46, 58, 'Caracteristicas')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 21, 'Marca'), (22, 26, 'Modelo'), (27, 33, 'Caracteristicas'), (34, 40, 'Conectividade'), (41, 45, 'Conectividade'), (46, 58, 'Caracteristicas')]
#
#
# Fone de Ouvido Intra-Auricular Bluetooth JBL Tune 125BT, Preto-JBLT125BTBLK
# (Fone de Ouvido, Intra-Auricular, Bluetooth, JBL, Tune 125BT)
# Predicted: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
#
#
# Fone de Ouvido Intra-Auricular Bluetooth JBL Tune 125BT, Branco-JBLT125BTWHT
# (Fone de Ouvido, Intra-Auricular, Bluetooth, JBL, Tune 125BT)
# Predicted: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (45, 55, 'Modelo')]
#
#
# Headset Gamer Sony Pulse 3D para PS5
# (Headset, Gamer, Sony, Pulse, 3D para, PS5)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 18, 'Marca'), (19, 24, 'Marca'), (25, 32, 'Modelo'), (33, 36, 'Conectividade')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 18, 'Modelo'), (19, 24, 'Marca'), (33, 36, 'Conectividade')]
#
#
# Caixa de Som Amplificada Multiuso LC 250 APP Bluetooth Preto - Bivolt
# (Caixa de Som, Amplificada, Multiuso, LC, 250 APP, Bluetooth, Preto, Bivolt)
# Predicted: [(0, 12, 'Categoria'), (13, 24, 'Potência'), (25, 33, 'Marca'), (34, 36, 'Modelo'), (37, 44, 'Tamanho'), (45, 54, 'Conectividade'), (55, 60, 'Cor'), (63, 69, 'Tensão')]
# True: [(0, 12, 'Categoria'), (13, 24, 'Potência'), (25, 33, 'Marca'), (34, 44, 'Modelo')]
#
#
# Caixa De Som Bazooka Acabamento De Couro 40W Pulse - SP265
# (Caixa De Som, Bazooka, De Couro, 40W, Pulse, SP265)
# Predicted: [(0, 12, 'Categoria'), (13, 20, 'Marca'), (32, 40, 'Caracteristicas'), (41, 44, 'Potência'), (45, 50, 'Marca'), (53, 58, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 20, 'Modelo'), (21, 40, 'Caracteristicas'), (41, 44, 'Potência'), (45, 50, 'Marca'), (53, 58, 'Modelo')]
#
#
# Fone de Ouvido Auricular JBL Bluetooth 300 Wave TWS, Branco - JBLW300TWSWHT
# (Fone de Ouvido, Auricular, JBL, Bluetooth, TWS, Branco, JBLW300TWSWHT)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (48, 51, 'Conectividade'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (39, 51, 'Potência'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
#
#
# Fone de Ouvido Auricular Bluetooth JBL Tune 215BT Pure Bass Hands-Free com Microfone, Preto-JBLT215BTBLK
# (Fone de Ouvido, Auricular, Bluetooth, JBL, Tune 215BT Pure Bass Hands-Free, com Microfone)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 34, 'Conectividade'), (35, 38, 'Marca'), (39, 70, 'Modelo'), (71, 84, 'Caracteristicas')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 34, 'Conectividade'), (35, 38, 'Marca'), (75, 84, 'Caracteristicas')]
#
#
# Fone De Ouvido Multikids Estéreo P2 Ajustável Frozen - PH127
# (De Ouvido, Multikids, Estéreo, P2, Ajustável, Frozen - PH127)
# Predicted: [(5, 14, 'Tamanho'), (15, 24, 'Marca'), (25, 32, 'Caracteristicas'), (33, 35, 'Conectividade'), (36, 45, 'Tipo'), (46, 60, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Marca'), (25, 32, 'Caracteristicas'), (33, 35, 'Conectividade'), (36, 45, 'Caracteristicas'), (46, 52, 'Modelo'), (55, 60, 'Modelo')]
#
#
# Earphone Metallic TWS com Conexão Bluetooth 4.2 Resistente à Água Pulse - PH275
# (Earphone, TWS, Conexão, Bluetooth 4.2, Resistente à Água, Pulse, PH275)
# Predicted: [(0, 8, 'Categoria'), (18, 21, 'Conectividade'), (26, 33, 'Conectividade'), (34, 47, 'Conectividade'), (48, 65, 'Caracteristicas'), (66, 71, 'Marca'), (74, 79, 'Modelo')]
# True: [(0, 21, 'Categoria'), (34, 47, 'Conectividade'), (48, 65, 'Caracteristicas'), (66, 71, 'Marca'), (74, 79, 'Modelo')]
#
#
# Caixa de Som portátil JBL Partybox 100 Bluetooth USB
# (Caixa de Som, portátil, JBL, Partybox 100, Bluetooth, USB)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 38, 'Modelo'), (39, 48, 'Conectividade'), (49, 52, 'Conectividade')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 38, 'Modelo'), (39, 48, 'Conectividade'), (49, 52, 'Conectividade')]
#
#
# Fone de ouvido JBL Endurance Sprint Red
# (Fone de ouvido, JBL, Endurance Sprint, Red)
# Predicted: [(0, 14, 'Categoria'), (15, 18, 'Marca'), (19, 35, 'Modelo'), (36, 39, 'Cor')]
# True: [(0, 14, 'Categoria'), (15, 18, 'Marca'), (19, 35, 'Modelo'), (36, 39, 'Cor')]
#
#
# Super Torre Double 15 4000W  - SP1000
# (Super, Torre, Double, 4000W, SP1000)
# Predicted: [(0, 5, 'Categoria'), (6, 11, 'Tipo'), (12, 18, 'Modelo'), (22, 27, 'Potência'), (31, 37, 'Modelo')]
# True: [(0, 21, 'Modelo'), (22, 27, 'Potência'), (31, 37, 'Modelo')]
#
#
# Fone de Ouvido Auricular Bluetooth JBL Tune 215BT Pure Bass Hands-Free com Microfone, Preto-JBLT215BTBLK
# (Fone de Ouvido, Auricular, Bluetooth, JBL, Tune 215BT Pure Bass Hands-Free, com Microfone)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 34, 'Conectividade'), (35, 38, 'Marca'), (39, 70, 'Modelo'), (71, 84, 'Caracteristicas')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 34, 'Conectividade'), (35, 38, 'Marca'), (39, 70, 'Modelo'), (75, 84, 'Caracteristicas')]
#
#
# Fone de Ouvido Pulse Intra Auricular Preto - PH330
# (Fone de Ouvido, Pulse, Intra Auricular, Preto, PH330)
# Predicted: [(0, 14, 'Categoria'), (15, 20, 'Marca'), (21, 36, 'Tipo'), (37, 42, 'Cor'), (45, 50, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 20, 'Marca'), (21, 36, 'Tipo'), (37, 42, 'Cor'), (45, 50, 'Modelo')]
#
#
# Fone De Ouvido Jbl Tune 500 Bluetooth
# (De Ouvido, Jbl, Tune 500, Bluetooth)
# Predicted: [(5, 14, 'Tamanho'), (15, 18, 'Marca'), (19, 27, 'Modelo'), (28, 37, 'Conectividade')]
# True: [(0, 14, 'Categoria'), (15, 18, 'Marca'), (28, 37, 'Conectividade')]
#
#
# Headset Gamer HyperX Cloud Stinger Core PC- HX-HSCSC2-BK/WW
# (Headset, Gamer, HyperX, Cloud Stinger Core PC-, HX-HSCSC2-BK/WW)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (21, 43, 'Modelo'), (44, 59, 'Modelo')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (21, 43, 'Modelo'), (44, 59, 'Modelo')]
#
#
# Fone de Ouvido Auricular JBL T215 TWS Branco
# (Fone de Ouvido, Auricular, JBL, TWS, Branco)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (34, 37, 'Conectividade'), (38, 44, 'Cor')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 33, 'Modelo'), (34, 37, 'Conectividade'), (38, 44, 'Cor')]
#
#
# Earphone TWS Touch Pulse Preto – PH320
# (Earphone, TWS, Touch, Pulse, Preto, PH320)
# Predicted: [(0, 8, 'Categoria'), (9, 12, 'Conectividade'), (13, 18, 'Caracteristicas'), (19, 24, 'Marca'), (25, 30, 'Cor'), (33, 38, 'Modelo')]
# True: [(0, 8, 'Categoria'), (9, 18, 'Modelo'), (19, 24, 'Marca'), (25, 30, 'Cor'), (33, 38, 'Modelo')]
#
#
# Caixa de Som Bluetooth 30W Preta Multilaser - SP313
# (Caixa de Som, Bluetooth, 30W, Preta, Multilaser, SP313)
# Predicted: [(0, 12, 'Categoria'), (13, 22, 'Conectividade'), (23, 26, 'Potência'), (27, 32, 'Cor'), (33, 43, 'Marca'), (46, 51, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 22, 'Conectividade'), (23, 26, 'Potência'), (33, 43, 'Marca'), (46, 51, 'Modelo')]
#
#
# Caixa De Som Bluetooth Wonderboom Raspberry Logitech
# (Caixa De Som, Bluetooth, Wonderboom, Raspberry, Logitech)
# Predicted: [(0, 12, 'Categoria'), (13, 22, 'Conectividade'), (23, 33, 'Modelo'), (34, 43, 'Conectividade'), (44, 52, 'Marca')]
# True: [(0, 12, 'Categoria'), (13, 22, 'Conectividade'), (23, 43, 'Modelo'), (44, 52, 'Marca')]
#
#
# Fone de Ouvido Bluetooth JBL Tune 510BT Preto JBLT510BTBLK
# (Fone de Ouvido, Bluetooth, JBL, Preto, JBLT510BTBLK)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 28, 'Marca'), (40, 45, 'Cor'), (46, 58, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 28, 'Marca'), (29, 39, 'Modelo'), (40, 45, 'Cor'), (46, 58, 'Modelo')]
#
#
# Fone de Ouvido Bluetooth GT Joy IPX4 | GT
# (Fone de Ouvido, Bluetooth, GT Joy IPX4, GT)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 36, 'Modelo'), (39, 41, 'Marca')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (39, 41, 'Marca')]
#
#
# Caixa de Som Portátil JBL GO 3 Bluetooth 5.1 À Prova D'água e Poeira IP67 Preto
# (Caixa de Som, Portátil, JBL, GO 3, Bluetooth 5.1, À Prova D'água e Poeira, IP67, Preto)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 30, 'Modelo'), (31, 44, 'Conectividade'), (45, 68, 'Caracteristicas'), (69, 73, 'Caracteristicas'), (74, 79, 'Cor')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 30, 'Modelo'), (31, 44, 'Conectividade'), (45, 68, 'Caracteristicas'), (69, 73, 'Caracteristicas'), (74, 79, 'Cor')]
#
#
# Fone de Ouvido Auricular JBL Bluetooth 300 Wave TWS, Branco - JBLW300TWSWHT
# (Fone de Ouvido, Auricular, JBL, Bluetooth, TWS, Branco, JBLW300TWSWHT)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (48, 51, 'Conectividade'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (39, 47, 'Modelo'), (48, 51, 'Conectividade'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
#
#
# TWS Airbud Preto Multilaser - PH358
# (TWS Airbud, Preto, Multilaser)
# Predicted: [(0, 10, 'Categoria'), (11, 16, 'Cor'), (17, 27, 'Marca')]
# True: [(0, 3, 'Conectividade'), (4, 10, 'Categoria'), (11, 16, 'Cor'), (17, 27, 'Marca'), (30, 35, 'Modelo')]
#
#
# Fone de Ouvido Auricular JBL T215 TWS , Preto
# (Fone de Ouvido, Auricular, JBL, TWS, Preto)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (34, 37, 'Conectividade'), (40, 45, 'Cor')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 33, 'Modelo'), (34, 37, 'Conectividade'), (40, 45, 'Cor')]
#
#
# Fone JBL TWS Wave Buds, Auricular, Bluetooth, Preto - JBLWBUDSBLK
# (Fone, JBL, TWS, Wave Buds, Auricular, Bluetooth, Preto)
# Predicted: [(0, 4, 'Categoria'), (5, 8, 'Marca'), (9, 12, 'Conectividade'), (13, 22, 'Modelo'), (24, 33, 'Tipo'), (35, 44, 'Conectividade'), (46, 51, 'Cor')]
# True: [(0, 4, 'Categoria'), (5, 8, 'Marca'), (9, 22, 'Modelo'), (24, 33, 'Tipo'), (35, 44, 'Conectividade'), (46, 51, 'Cor'), (54, 65, 'Caracteristicas')]
#
#
# Headset Gamer HyperX Cloud Stinger Core PC- HX-HSCSC2-BK/WW
# (Headset, Gamer, HyperX, Cloud Stinger Core PC-, HX-HSCSC2-BK/WW)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (21, 43, 'Modelo'), (44, 59, 'Modelo')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (21, 43, 'Modelo'), (44, 59, 'Modelo')]
#
#
# Soundbar 5.1 Canais Bluetooth 280W RMS com Subwoofer sem Fio e Caixas Surround | GT
# (Soundbar, 5.1 Canais, Bluetooth, 280W RMS, com Subwoofer sem Fio, GT)
# Predicted: [(0, 8, 'Categoria'), (9, 19, 'Caracteristicas'), (20, 29, 'Conectividade'), (30, 38, 'Potência'), (39, 60, 'Item adicional'), (81, 83, 'Marca')]
# True: [(0, 8, 'Categoria'), (20, 29, 'Conectividade'), (30, 38, 'Potência'), (39, 78, 'Item adicional'), (81, 83, 'Marca')]
#
#
# Fone de Ouvido HyperX Cloud Buds, Bluetooth HEBBXX-MC-RD/G
# (Fone de Ouvido, HyperX, Cloud Buds, Bluetooth, HEBBXX-MC-RD/G)
# Predicted: [(0, 14, 'Categoria'), (15, 21, 'Marca'), (22, 32, 'Modelo'), (34, 43, 'Conectividade'), (44, 58, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 21, 'Marca'), (22, 32, 'Modelo'), (34, 43, 'Conectividade'), (44, 58, 'Modelo')]
#
#
# Headphone Bluetooth GT White com Microfone Integrado | GT
# (Headphone, Bluetooth, GT, White, Microfone Integrado, GT)
# Predicted: [(0, 9, 'Categoria'), (10, 19, 'Conectividade'), (20, 22, 'Marca'), (23, 28, 'Cor'), (33, 52, 'Caracteristicas'), (55, 57, 'Marca')]
# True: [(10, 19, 'Conectividade'), (20, 22, 'Marca'), (23, 28, 'Cor'), (33, 52, 'Caracteristicas'), (55, 57, 'Marca')]
#
#
# Soundbar 2.0 Canais Bluetooth 80W RMS com HDMI ARC e Entrada Óptica | GT
# (Soundbar, Bluetooth, 80W RMS, HDMI, ARC e, Entrada, Óptica, GT)
# Predicted: [(0, 8, 'Categoria'), (20, 29, 'Conectividade'), (30, 37, 'Potência'), (42, 46, 'Conectividade'), (47, 52, 'Conectividade'), (53, 60, 'Conectividade'), (61, 67, 'Conectividade'), (70, 72, 'Marca')]
# True: [(0, 8, 'Categoria'), (9, 19, 'Caracteristicas'), (20, 29, 'Conectividade'), (30, 37, 'Potência'), (42, 46, 'Conectividade'), (47, 52, 'Conectividade'), (53, 67, 'Conectividade'), (70, 72, 'Marca')]
#
#
# Caixa de Som portátil JBL Partybox 100 Bluetooth USB
# (Caixa de Som, portátil, JBL, Partybox 100, Bluetooth, USB)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 38, 'Modelo'), (39, 48, 'Conectividade'), (49, 52, 'Conectividade')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 38, 'Modelo'), (39, 48, 'Conectividade'), (49, 52, 'Conectividade')]
#
#
# Headset Gamer HyperX CloudX  Xbox Preto e Cinza HHSC2-CG-SL/G
# (Headset, Gamer, HyperX, CloudX, Xbox, Preto e Cinza)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (21, 27, 'Modelo'), (29, 33, 'Conectividade'), (34, 47, 'Cor')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (21, 27, 'Modelo'), (29, 33, 'Conectividade'), (34, 47, 'Cor')]
#
#
# Fone de Ouvido Auricular JBL Wave 200TWS, Azul - JBLW200TWSBLU
# (Fone de Ouvido, Auricular, JBL, Wave 200TWS, Azul, JBLW200TWSBLU)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 40, 'Modelo'), (42, 46, 'Cor'), (49, 62, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 33, 'Modelo'), (34, 40, 'Potência'), (42, 46, 'Cor'), (49, 62, 'Modelo')]
#
#
# Fone de Ouvido Multilaser Bluetooth Mono Auricular Preto - AU207
# (Fone de Ouvido, Multilaser, Bluetooth, Mono Auricular, Preto, AU207)
# Predicted: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 35, 'Conectividade'), (36, 50, 'Categoria'), (51, 56, 'Cor'), (59, 64, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 35, 'Conectividade'), (51, 56, 'Cor'), (59, 64, 'Modelo')]
#
#
# Headset Gamer Corsair HS70 Wireless Carbono, 7.1 Surround, Branco - CA-9011177-NA
# (Headset, Gamer, Corsair, HS70, Wireless, Carbono, 7.1 Surround, Branco)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 21, 'Marca'), (22, 26, 'Conectividade'), (27, 35, 'Conectividade'), (36, 43, 'Caracteristicas'), (45, 57, 'Caracteristicas'), (59, 65, 'Cor')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 21, 'Marca'), (22, 26, 'Modelo'), (27, 35, 'Conectividade'), (36, 43, 'Caracteristicas'), (45, 57, 'Caracteristicas'), (59, 65, 'Cor')]
#
#
# Fone de Ouvido Bluetooth Apple Beats Flex, Cinza-MYME2BE/A
# (Fone de Ouvido, Bluetooth, Apple, Beats Flex, Cinza-MYME2BE/)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 30, 'Marca'), (31, 41, 'Modelo'), (43, 57, 'Caracteristicas')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 30, 'Marca'), (31, 41, 'Modelo')]
#
#
# Caixa de Som Amplificada Multiuso LC 250 APP Bluetooth  Vermelho
# (Caixa de Som, Amplificada, Multiuso, LC, 250 APP, Bluetooth, Vermelho)
# Predicted: [(0, 12, 'Categoria'), (13, 24, 'Potência'), (25, 33, 'Marca'), (34, 36, 'Modelo'), (37, 44, 'Tamanho'), (45, 54, 'Conectividade'), (56, 64, 'Cor')]
# True: [(0, 12, 'Categoria'), (13, 24, 'Potência'), (25, 33, 'Modelo'), (34, 44, 'Modelo'), (45, 54, 'Conectividade'), (56, 64, 'Cor')]
#
#
# Caixa De Som Boombox 15W Rms Preta - SP182
# (Caixa De Som, Boombox, 15W Rms, Preta, SP182)
# Predicted: [(0, 12, 'Categoria'), (13, 20, 'Marca'), (21, 28, 'Potência'), (29, 34, 'Cor'), (37, 42, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 20, 'Marca'), (21, 28, 'Potência'), (29, 34, 'Cor'), (37, 42, 'Modelo')]
#
#
# Fones de ouvido esportivos JBL Endurance RUNBT
# (Fones de ouvido, esportivos, JBL, Endurance)
# Predicted: [(0, 15, 'Categoria'), (16, 26, 'Tipo'), (27, 30, 'Marca'), (31, 40, 'Modelo')]
# True: [(0, 15, 'Categoria'), (16, 26, 'Caracteristicas'), (27, 30, 'Marca'), (31, 46, 'Modelo')]
#
#
# Fone De Ouvido Bluetooth JBL T510 Azul
# (De Ouvido, Bluetooth, JBL, T510, Azul)
# Predicted: [(5, 14, 'Tamanho'), (15, 24, 'Conectividade'), (25, 28, 'Marca'), (29, 33, 'Modelo'), (34, 38, 'Cor')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 28, 'Marca'), (29, 33, 'Modelo'), (34, 38, 'Cor')]
#
#
# Caixa de Som Amvox ACA-150 Usb, Card, Aux, Bluetooth, Radio FM, 100W Preto - Bivolt
# (Caixa de Som, Amvox, ACA-150, Usb, Bluetooth, Radio FM, 100W, Preto, Bivolt)
# Predicted: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 26, 'Modelo'), (27, 30, 'Conectividade'), (43, 52, 'Conectividade'), (54, 62, 'Caracteristicas'), (64, 68, 'Potência'), (69, 74, 'Cor'), (77, 83, 'Tensão')]
# True: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 26, 'Modelo'), (27, 30, 'Conectividade'), (32, 36, 'Conectividade'), (38, 41, 'Conectividade'), (43, 52, 'Conectividade'), (54, 62, 'Caracteristicas'), (64, 68, 'Potência'), (69, 74, 'Cor'), (77, 83, 'Marca')]
#
#
# Toca-Disco ObaWave Conversor de Vinil Obabox - OB007
# (Toca-Disco ObaWave, Conversor, Obabox, OB007)
# Predicted: [(0, 18, 'Categoria'), (19, 28, 'Caracteristicas'), (38, 44, 'Marca'), (47, 52, 'Modelo')]
# True: [(0, 10, 'Categoria'), (11, 37, 'Modelo'), (38, 44, 'Marca'), (47, 52, 'Modelo')]
#
#
# Caixa de Som Xplode 3 300W Bluetooth Pulse - SP606
# (Caixa de Som, Xplode 3, 300W, Bluetooth, Pulse, SP606)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Modelo'), (22, 26, 'Potência'), (27, 36, 'Conectividade'), (37, 42, 'Marca'), (45, 50, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Modelo'), (22, 26, 'Potência'), (27, 36, 'Conectividade'), (37, 42, 'Marca'), (45, 50, 'Modelo')]
#
#
# Fone de Ouvido Pulse Intra Auricular Branco - PH329
# (Fone de Ouvido, Pulse, Intra Auricular, Branco)
# Predicted: [(0, 14, 'Categoria'), (15, 20, 'Marca'), (21, 36, 'Tipo'), (37, 43, 'Cor')]
# True: [(0, 14, 'Categoria'), (15, 20, 'Marca'), (21, 36, 'Tipo'), (37, 43, 'Cor'), (46, 51, 'Modelo')]
#
#
# Headset Para Capacete Multilaser Bluetooth Musicas e Ligações Handsfree Preto  - MT603
# (Headset, Para Capacete, Multilaser, Bluetooth, Musicas e Ligações, Handsfree, Preto, MT603)
# Predicted: [(0, 7, 'Categoria'), (8, 21, 'Caracteristicas'), (22, 32, 'Marca'), (33, 42, 'Conectividade'), (43, 61, 'Caracteristicas'), (62, 71, 'Caracteristicas'), (72, 77, 'Cor'), (81, 86, 'Modelo')]
# True: [(0, 7, 'Categoria'), (8, 21, 'Tipo'), (22, 32, 'Marca'), (33, 42, 'Conectividade'), (43, 61, 'Caracteristicas'), (62, 71, 'Caracteristicas'), (72, 77, 'Cor'), (81, 86, 'Modelo')]
#
#
# Soundbar 2.1 Canais Bluetooth 180W RMS com Subwoofer e USB | GT
# (Soundbar, Bluetooth, RMS, com Subwoofer, USB, GT)
# Predicted: [(0, 8, 'Categoria'), (20, 29, 'Conectividade'), (35, 38, 'Caracteristicas'), (39, 52, 'Item adicional'), (55, 58, 'Conectividade'), (61, 63, 'Marca')]
# True: [(0, 8, 'Categoria'), (9, 19, 'Modelo'), (20, 29, 'Conectividade'), (30, 38, 'Potência'), (39, 52, 'Item adicional'), (55, 58, 'Conectividade'), (61, 63, 'Marca')]
#
#
# PulseBox 2x Woofers 6.5 Polegadas 600W Pulse - SP504
# (PulseBox 2x, Woofers, 6.5 Polegadas, 600W, Pulse)
# Predicted: [(0, 11, 'Categoria'), (12, 19, 'Caracteristicas'), (20, 33, 'Tamanho'), (34, 38, 'Potência'), (39, 44, 'Marca')]
# True: [(0, 8, 'Modelo'), (9, 19, 'Caracteristicas'), (20, 33, 'Tamanho'), (34, 44, 'Potência'), (47, 52, 'Modelo')]
#
#
# Caixa de Som Pulse Supreme 500W BT/AUX/USB/TWS/LED - SP602
# (Caixa de Som, Pulse, Supreme, 500W, BT/, AUX, USB, TWS, SP602)
# Predicted: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 26, 'Caracteristicas'), (27, 31, 'Potência'), (32, 35, 'Conectividade'), (35, 38, 'Conectividade'), (39, 42, 'Conectividade'), (43, 46, 'Conectividade'), (53, 58, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 26, 'Modelo'), (27, 31, 'Potência'), (32, 50, 'Conectividade'), (53, 58, 'Modelo')]
#
#
# Caixa de Som JBL Flip 5, Bluetooth, 20W RMS, À Prova D'Água, Azul - JBLFLIP5BL
# (Caixa de Som, JBL, Flip 5, Bluetooth, 20W RMS, À Prova D'Água, Azul, JBLFLIP5BL)
# Predicted: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 23, 'Modelo'), (25, 34, 'Conectividade'), (36, 43, 'Potência'), (45, 59, 'Caracteristicas'), (61, 65, 'Cor'), (68, 78, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 23, 'Modelo'), (25, 34, 'Conectividade'), (36, 43, 'Potência'), (45, 59, 'Caracteristicas'), (61, 65, 'Cor'), (68, 78, 'Modelo')]
#
#
# Headphone Bluetooth GT Fun com Entrada MicroSD | GT
# (Headphone, Bluetooth, GT Fun, Entrada, MicroSD, GT)
# Predicted: [(0, 9, 'Categoria'), (10, 19, 'Conectividade'), (20, 26, 'Modelo'), (31, 38, 'Conectividade'), (39, 46, 'Conectividade'), (49, 51, 'Marca')]
# True: [(0, 9, 'Categoria'), (10, 19, 'Conectividade'), (20, 26, 'Modelo'), (31, 46, 'Conectividade'), (49, 51, 'Marca')]
#
#
# Headset Gamer HyperX Cloud Stinger Core 7.1 - HHSS1C-AA-BK/G
# (Headset, Gamer, HyperX, Cloud Stinger Core 7.1, HHSS1C-AA-BK/G)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (21, 43, 'Modelo'), (46, 60, 'Modelo')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (21, 43, 'Modelo'), (46, 60, 'Modelo')]
#
#
# Caixa De Som Speaker Bluetooth 150W Rms De Potência Pulse - SP283
# (Caixa De Som, Speaker, Bluetooth, 150W Rms, De Potência, Pulse, SP283)
# Predicted: [(0, 12, 'Categoria'), (13, 20, 'Categoria'), (21, 30, 'Conectividade'), (31, 39, 'Potência'), (40, 51, 'Tipo'), (52, 57, 'Marca'), (60, 65, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 20, 'Categoria'), (21, 30, 'Conectividade'), (31, 39, 'Potência'), (52, 57, 'Marca'), (60, 65, 'Modelo')]
#
#
# Caixa de Som 2.1 Gamer 30W RMS RGB Multilaser - SP952
# (Caixa de Som, 2.1 Gamer, 30W RMS, Multilaser, SP952)
# Predicted: [(0, 12, 'Categoria'), (13, 22, 'Modelo'), (23, 30, 'Potência'), (35, 45, 'Marca'), (48, 53, 'Modelo')]
# True: [(0, 12, 'Categoria'), (17, 22, 'Caracteristicas'), (23, 30, 'Potência'), (31, 34, 'Caracteristicas'), (35, 45, 'Marca')]
#
#
# Soundbar 2.1 Canais Bluetooth 180W RMS com Subwoofer e USB | GT
# (Soundbar, Bluetooth, RMS, com Subwoofer, USB, GT)
# Predicted: [(0, 8, 'Categoria'), (20, 29, 'Conectividade'), (35, 38, 'Caracteristicas'), (39, 52, 'Item adicional'), (55, 58, 'Conectividade'), (61, 63, 'Marca')]
# True: [(0, 8, 'Categoria'), (9, 19, 'Modelo'), (20, 29, 'Conectividade'), (30, 38, 'Potência'), (39, 52, 'Item adicional'), (55, 58, 'Conectividade'), (61, 63, 'Marca')]
#
#
# Kit com 2 Headphone Bluetooth GT Follow Verde e Amarelo | GT
# (Kit com 2, Headphone, Bluetooth, GT, Follow, Verde e Amarelo, GT)
# Predicted: [(0, 9, 'Categoria'), (10, 19, 'Categoria'), (20, 29, 'Conectividade'), (30, 32, 'Marca'), (33, 39, 'Modelo'), (40, 55, 'Cor'), (58, 60, 'Marca')]
# True: [(0, 19, 'Modelo'), (20, 29, 'Conectividade'), (30, 32, 'Marca'), (33, 39, 'Modelo'), (58, 60, 'Marca')]
#
#
# Fone de Ouvido Auricular JBL Bluetooth 300 Wave TWS, Branco - JBLW300TWSWHT
# (Fone de Ouvido, Auricular, JBL, Bluetooth, TWS, Branco, JBLW300TWSWHT)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (48, 51, 'Conectividade'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (29, 38, 'Conectividade'), (39, 51, 'Potência'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
#
#
# Fone de Ouvido Auricular JBL Bluetooth 300 Wave TWS, Branco - JBLW300TWSWHT
# (Fone de Ouvido, Auricular, JBL, Bluetooth, TWS, Branco, JBLW300TWSWHT)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (48, 51, 'Conectividade'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (39, 51, 'Potência'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
#
#
# Caixa de Som Cubo Speaker 3W Branco Multilaser - SP306
# (Caixa de Som, Cubo Speaker, 3W, Branco, Multilaser, SP306)
# Predicted: [(0, 12, 'Categoria'), (13, 25, 'Modelo'), (26, 28, 'Potência'), (29, 35, 'Cor'), (36, 46, 'Marca'), (49, 54, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 17, 'Modelo'), (18, 25, 'Categoria'), (26, 28, 'Modelo'), (29, 35, 'Cor'), (36, 46, 'Marca'), (49, 54, 'Modelo')]
#
#
# Fone De Ouvido Aux. P2 Large Preto Pulse - PH226
# (De Ouvido, Aux., Large, Preto, Pulse)
# Predicted: [(5, 14, 'Tamanho'), (15, 19, 'Conectividade'), (23, 28, 'Modelo'), (29, 34, 'Cor'), (35, 40, 'Marca')]
# True: [(0, 14, 'Categoria'), (15, 22, 'Conectividade'), (23, 28, 'Modelo'), (29, 34, 'Cor'), (35, 40, 'Marca')]
#
#
# Fone Earhook In-Ear Sport Metallic Áudio Bluetooth Amarelo Pulse - PH254
# (Fone, Earhook In-Ear Sport, Áudio, Bluetooth, Amarelo, Pulse, PH254)
# Predicted: [(0, 4, 'Categoria'), (5, 25, 'Modelo'), (35, 40, 'Caracteristicas'), (41, 50, 'Conectividade'), (51, 58, 'Cor'), (59, 64, 'Marca'), (67, 72, 'Modelo')]
# True: [(0, 4, 'Categoria'), (5, 40, 'Modelo'), (41, 50, 'Conectividade'), (51, 58, 'Cor'), (59, 64, 'Marca'), (67, 72, 'Modelo')]
#
#
# Fone De Ouvido Com Fio Pulse 2 Branco Motorola
# (De Ouvido, Com Fio, Pulse, 2, Branco, Motorola)
# Predicted: [(5, 14, 'Tamanho'), (15, 22, 'Caracteristicas'), (23, 28, 'Marca'), (29, 30, 'Modelo'), (31, 37, 'Cor'), (38, 46, 'Marca')]
# True: [(0, 14, 'Categoria'), (38, 46, 'Marca')]
#
#
# Suporte Universal para Projetor 3 em 1 | GT
# (Suporte, Universal para Projetor 3 em 1, GT)
# Predicted: [(0, 7, 'Categoria'), (8, 38, 'Modelo'), (41, 43, 'Marca')]
# True: [(0, 31, 'Categoria'), (32, 38, 'Modelo'), (41, 43, 'Marca')]
#
#
# Caixa de Som Amplificada Amvox ACA 1001, Bluetooth, USB, Karaokê, 1000W, Preto - Bivolt
# (Caixa de Som, Amplificada, Amvox, ACA 1001, Bluetooth, USB, Karaokê, 1000W, Preto, Bivolt)
# Predicted: [(0, 12, 'Categoria'), (13, 24, 'Potência'), (25, 30, 'Marca'), (31, 39, 'Modelo'), (41, 50, 'Conectividade'), (52, 55, 'Conectividade'), (57, 64, 'Caracteristicas'), (66, 71, 'Potência'), (73, 78, 'Cor'), (81, 87, 'Tensão')]
# True: [(0, 12, 'Categoria'), (25, 30, 'Marca'), (31, 39, 'Modelo'), (41, 56, 'Conectividade'), (57, 64, 'Conectividade'), (66, 72, 'Potência'), (73, 78, 'Cor'), (81, 87, 'Marca')]
#
#
# Headset Gamer GT Attack 7.1 Canais com LED para Desktop | GT Gamer
# (Headset, Gamer, GT, Attack 7.1 Canais, LED para Desktop, GT, Gamer)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 16, 'Marca'), (17, 34, 'Modelo'), (39, 55, 'Caracteristicas'), (58, 60, 'Marca'), (61, 66, 'Caracteristicas')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 16, 'Marca'), (17, 34, 'Modelo'), (39, 57, 'Caracteristicas'), (58, 60, 'Marca'), (61, 66, 'Caracteristicas')]
#
#
# Caixa de Som Torre 500W RMS DJ Mixer Goldentec Bluetooth, 2 USBs e Função DJ (CSDJG1206)
# (Caixa de Som, Torre, 500W RMS, DJ, Mixer, Goldentec, Bluetooth, USBs)
# Predicted: [(0, 12, 'Categoria'), (13, 18, 'Tipo'), (19, 27, 'Potência'), (28, 30, 'Caracteristicas'), (31, 36, 'Caracteristicas'), (37, 46, 'Marca'), (47, 56, 'Conectividade'), (60, 64, 'Conectividade')]
# True: [(0, 12, 'Categoria'), (13, 18, 'Tipo'), (19, 27, 'Modelo'), (28, 36, 'Modelo'), (37, 46, 'Marca'), (47, 56, 'Conectividade'), (58, 64, 'Conectividade'), (67, 76, 'Item adicional')]
#
#
# Tela De Projeção C/ Tripé 1,80x1,80m 97 Polegadas Retrátil - AC354
# (1,80x1,80m, 97 Polegadas, Retrátil)
# Predicted: [(26, 36, 'Tamanho'), (37, 49, 'Potência'), (50, 58, 'Tipo')]
# True: [(0, 16, 'Categoria'), (20, 25, 'Item adicional'), (26, 36, 'Tamanho'), (37, 49, 'Tamanho'), (50, 58, 'Caracteristicas'), (61, 66, 'Modelo')]
#
#
# Caixa De Som Bluetooth Multimídia CS-M33BT Exbom - 03050
# (Caixa De Som, Bluetooth, Multimídia, CS-M33BT, Exbom)
# Predicted: [(0, 12, 'Categoria'), (13, 22, 'Conectividade'), (23, 33, 'Conectividade'), (34, 42, 'Conectividade'), (43, 48, 'Marca')]
# True: [(0, 12, 'Categoria'), (13, 22, 'Conectividade'), (23, 33, 'Conectividade'), (43, 48, 'Marca')]
#
#
# Caixa de Som portátil JBL Partybox 100 Bluetooth USB
# (Caixa de Som, portátil, JBL, Partybox 100, Bluetooth, USB)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 38, 'Modelo'), (39, 48, 'Conectividade'), (49, 52, 'Conectividade')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 38, 'Modelo'), (39, 48, 'Conectividade'), (49, 52, 'Conectividade')]
#
#
# Fone de Ouvido Auricular Bluetooth JBL Tune 215BT Pure Bass Hands-Free com Microfone, Preto-JBLT215BTBLK
# (Fone de Ouvido, Auricular, Bluetooth, JBL, Tune 215BT Pure Bass Hands-Free, com Microfone)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 34, 'Conectividade'), (35, 38, 'Marca'), (39, 70, 'Modelo'), (71, 84, 'Caracteristicas')]
# True: [(0, 14, 'Categoria'), (39, 49, 'Modelo'), (50, 59, 'Caracteristicas'), (60, 70, 'Caracteristicas'), (75, 84, 'Caracteristicas')]
#
#
# Fone de Ouvido Intra-Auricular Bluetooth JBL Tune 125BT, Preto-JBLT125BTBLK
# (Fone de Ouvido, Intra-Auricular, Bluetooth, JBL, Tune 125BT)
# Predicted: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
#
#
# Kit Tablet Samsung Galaxy S7 FE 4G 128GB Prata com S Pen + Fone de Ouvido Bluetooth Samsung Galaxy Buds Live Preto
# (Kit Tablet, Samsung, Galaxy S7, FE 4G 128GB, Prata, S Pen + Fone de Ouvido, Bluetooth, Samsung, Galaxy Buds Live, Preto)
# Predicted: [(0, 10, 'Categoria'), (11, 18, 'Marca'), (19, 28, 'Modelo'), (29, 40, 'Modelo'), (41, 46, 'Cor'), (51, 73, 'Modelo'), (74, 83, 'Conectividade'), (84, 91, 'Marca'), (92, 108, 'Modelo'), (109, 114, 'Cor')]
# True: [(11, 18, 'Marca'), (41, 46, 'Cor'), (74, 83, 'Conectividade'), (84, 91, 'Marca'), (92, 108, 'Modelo'), (109, 114, 'Cor')]
#
#
# Caixa De Som Multilaser Boombox 20W Rms Cd/Usb/Sd/Fm/Aux. Rosa E Preto- SP179
# (Caixa De Som, Multilaser, Boombox, 20W Rms, Cd, Usb/Sd/Fm, Rosa E Preto-, SP179)
# Predicted: [(0, 12, 'Categoria'), (13, 23, 'Marca'), (24, 31, 'Marca'), (32, 39, 'Potência'), (40, 42, 'Caracteristicas'), (43, 52, 'Conectividade'), (58, 71, 'Cor'), (72, 77, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 23, 'Marca'), (24, 31, 'Modelo'), (32, 39, 'Potência'), (40, 42, 'Conectividade'), (43, 46, 'Conectividade'), (47, 49, 'Conectividade'), (50, 52, 'Conectividade'), (53, 57, 'Conectividade'), (58, 62, 'Cor')]
#
#
# Caixa de Som Portátil LG Xboom Go XG9 Power, Bluetooth, 80W + 40W RMS, Bateria Recarregável, Sound Boost - XG9QBK.ABRALLK
# (Caixa de Som, Portátil, LG, Xboom, Go XG9, Power, Bluetooth, 80W, 40W RMS, Bateria Recarregável, Sound Boost)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 24, 'Marca'), (25, 30, 'Marca'), (31, 37, 'Modelo'), (38, 43, 'Marca'), (45, 54, 'Conectividade'), (56, 59, 'Potência'), (62, 69, 'Potência'), (71, 91, 'Caracteristicas'), (93, 104, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (25, 43, 'Modelo'), (45, 54, 'Conectividade'), (56, 69, 'Potência'), (71, 91, 'Caracteristicas'), (93, 104, 'Caracteristicas'), (107, 121, 'Modelo')]
#
#
# Fone De Ouvido Multilaser Headphone Vibe Design Retro P2 Rosa - PH055
# (De Ouvido, Multilaser, Headphone, Vibe, Design Retro, P2, Rosa, PH055)
# Predicted: [(5, 14, 'Tamanho'), (15, 25, 'Marca'), (26, 35, 'Tipo'), (36, 40, 'Modelo'), (41, 53, 'Caracteristicas'), (54, 56, 'Conectividade'), (57, 61, 'Cor'), (64, 69, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 35, 'Tipo'), (36, 40, 'Modelo'), (41, 53, 'Caracteristicas'), (54, 56, 'Conectividade'), (57, 61, 'Cor'), (64, 69, 'Modelo')]
#
#
# Headset Gamer ASTRO Gaming A40 TR + MixAmp Pro TR Gen 4 com Áudio Dolby - para Xbox One, PC e Mac - Preto/Vermelho
# (Headset, Gamer, ASTRO, Gaming, A40 TR, TR Gen 4, Áudio, Dolby, Xbox, PC, Preto/Vermelho)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 19, 'Caracteristicas'), (20, 26, 'Caracteristicas'), (27, 33, 'Modelo'), (47, 55, 'Modelo'), (60, 65, 'Caracteristicas'), (66, 71, 'Caracteristicas'), (79, 83, 'Conectividade'), (89, 91, 'Conectividade'), (100, 114, 'Cor')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 26, 'Marca'), (27, 55, 'Modelo'), (60, 71, 'Caracteristicas'), (79, 97, 'Conectividade'), (100, 114, 'Cor')]
#
#
# Headset Gamer Trust GXT 404B Rana para PS4 Drivers 40mm, Preto/Azul - T23309
# (Headset, Gamer, Trust, GXT 404B Rana para PS4, Drivers 40mm, Preto/Azul, T23309)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 19, 'Marca'), (20, 42, 'Modelo'), (43, 55, 'Caracteristicas'), (57, 67, 'Cor'), (70, 76, 'Modelo')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 19, 'Marca'), (20, 33, 'Modelo'), (39, 42, 'Conectividade'), (43, 55, 'Tamanho'), (57, 67, 'Cor'), (70, 76, 'Modelo')]
#
#
# Caixa Acústica Philco PCX16000 - Bivolt
# (Caixa Acústica, Philco, PCX16000 - Bivolt)
# Predicted: [(0, 14, 'Categoria'), (15, 21, 'Marca'), (22, 39, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 21, 'Marca'), (22, 30, 'Modelo'), (33, 39, 'Tensão')]
#
#
# Caixa De Som 10W Rms Bluetooth Multilaser- SP286
# (Caixa De Som, 10W Rms, Bluetooth, SP286)
# Predicted: [(0, 12, 'Categoria'), (13, 20, 'Potência'), (21, 30, 'Conectividade'), (43, 48, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 20, 'Potência'), (21, 30, 'Conectividade'), (43, 48, 'Modelo')]
#
#
# Fones de ouvido JBL Endurance RUN intra-auriculares
# (Fones de ouvido, JBL, Endurance, intra-auriculares)
# Predicted: [(0, 15, 'Categoria'), (16, 19, 'Marca'), (20, 29, 'Modelo'), (34, 51, 'Tipo')]
# True: [(0, 15, 'Categoria'), (16, 19, 'Marca'), (20, 33, 'Modelo'), (34, 51, 'Tipo')]
#
#
# Caixa de Som JBL Partybox 710 TWS
# (Caixa de Som, JBL, Partybox 710, TWS)
# Predicted: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 29, 'Modelo'), (30, 33, 'Conectividade')]
# True: [(0, 12, 'Categoria'), (17, 29, 'Modelo'), (30, 33, 'Conectividade')]
#
#
# Fone De Ouvido Pop Bluetooth P2 Branco Multilaser - PH247
# (De Ouvido, Pop, Bluetooth, P2, Branco, Multilaser, PH247)
# Predicted: [(5, 14, 'Tamanho'), (15, 18, 'Modelo'), (19, 28, 'Conectividade'), (29, 31, 'Conectividade'), (32, 38, 'Cor'), (39, 49, 'Marca'), (52, 57, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 18, 'Modelo'), (19, 28, 'Conectividade'), (29, 31, 'Conectividade'), (32, 38, 'Cor'), (39, 49, 'Marca'), (52, 57, 'Modelo')]
#
#
# Combo Kids - Fone De Ouvido Multilaser Kids Happy e KidWatch Infantil 4G + Wi-Fi Controle Parental Azul - P92001K
# (Combo Kids -, De Ouvido, Multilaser, Kids Happy e KidWatch Infantil 4, Wi-Fi, Controle Parental, Azul, P92001K)
# Predicted: [(0, 12, 'Categoria'), (18, 27, 'Tipo'), (28, 38, 'Marca'), (39, 71, 'Modelo'), (75, 80, 'Conectividade'), (81, 98, 'Caracteristicas'), (99, 103, 'Cor'), (106, 113, 'Caracteristicas')]
# True: [(0, 27, 'Categoria'), (28, 38, 'Marca'), (39, 69, 'Modelo'), (70, 72, 'Conectividade'), (75, 80, 'Conectividade'), (81, 98, 'Caracteristicas'), (99, 103, 'Cor'), (106, 113, 'Modelo')]
#
#
# Caixa de Som Portátil JBL GO 3 Bluetooth 5.1 À Prova D'água e Poeira IP67 Azul
# (Caixa de Som, Portátil, JBL, GO 3, Bluetooth 5.1, À Prova D'água e Poeira, IP67, Azul)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 30, 'Modelo'), (31, 44, 'Conectividade'), (45, 68, 'Caracteristicas'), (69, 73, 'Caracteristicas'), (74, 78, 'Cor')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 30, 'Modelo'), (31, 44, 'Conectividade'), (45, 68, 'Caracteristicas'), (69, 73, 'Caracteristicas'), (74, 78, 'Cor')]
#
#
# Fone De Ouvido A Prova D'água Multilaser - ES081
# (A Prova D'água, Multilaser, ES081)
# Predicted: [(15, 29, 'Caracteristicas'), (30, 40, 'Marca'), (43, 48, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 29, 'Caracteristicas'), (30, 40, 'Marca'), (43, 48, 'Modelo')]
#
#
# Earhook Sport Stereo Audio - PH205
# (Earhook, Sport, Stereo, Audio, PH205)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Modelo'), (14, 20, 'Caracteristicas'), (21, 26, 'Caracteristicas'), (29, 34, 'Modelo')]
# True: [(0, 26, 'Modelo'), (29, 34, 'Modelo')]
#
#
# Headset Gamer HyperX Cloud Stinger PS4, Preto - HX-HSCSS-BK/AM
# (Headset, Gamer, HyperX, Cloud Stinger PS4, Preto, HX-HSCSS-BK/AM)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (21, 38, 'Modelo'), (40, 45, 'Cor'), (48, 62, 'Modelo')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (21, 38, 'Modelo'), (40, 45, 'Cor'), (48, 62, 'Conectividade')]
#
#
# Fone de Ouvido Intra-Auricular Bluetooth JBL Tune 125BT, Branco-JBLT125BTWHT
# (Fone de Ouvido, Intra-Auricular, Bluetooth, JBL, Tune 125BT)
# Predicted: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 55, 'Modelo')]
#
#
# Earhook Sport Stereo Áudio - PH204
# (Earhook, Sport, Stereo, Áudio, PH204)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Modelo'), (14, 20, 'Caracteristicas'), (21, 26, 'Caracteristicas'), (29, 34, 'Modelo')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Marca'), (21, 26, 'Caracteristicas'), (29, 34, 'Modelo')]
#
#
#                  precision    recall  f1-score   support
#
# Caracteristicas       0.54      0.68      0.60        53
#       Categoria       0.85      0.82      0.84        96
#   Conectividade       0.70      0.77      0.73        99
#             Cor       0.87      0.91      0.89        45
#  Item adicional       0.75      0.50      0.60         6
#           Marca       0.86      0.96      0.90        94
#          Modelo       0.65      0.59      0.62       125
#               O       0.00      0.00      0.00       143
#        Potência       0.68      0.63      0.65        27
#         Tamanho       0.15      0.40      0.22         5
#          Tensão       0.00      0.00      0.00         1
#            Tipo       0.76      0.93      0.84        28
#
#        accuracy                           0.61       722
#       macro avg       0.57      0.60      0.58       722
#    weighted avg       0.59      0.61      0.60       722

# %%
# Convert test data to spaCy Examples
examples = [Example.from_dict(nlp.make_doc(text), annotations) for text, annotations in test_data_spacy]

# Evaluate the model using SpaCy's built-in evaluate function
results = nlp.evaluate(examples)

# Print the evaluation results
print(f"Precision: {results['ents_p']:.4f}")
print(f"Recall: {results['ents_r']:.4f}")
print(f"F1-score: {results['ents_f']:.4f}")
print(f"Entity-wise results: {results['ents_per_type']}")
# Out:
# Precision: 0.7243
# Recall: 0.7668
# F1-score: 0.7450
# Entity-wise results: {'Categoria': {'p': 0.8494623655913979, 'r': 0.8229166666666666, 'f': 0.8359788359788359}, 'Conectividade': {'p': 0.7037037037037037, 'r': 0.7676767676767676, 'f': 0.7342995169082125}, 'Caracteristicas': {'p': 0.5373134328358209, 'r': 0.6792452830188679, 'f': 0.5999999999999999}, 'Item adicional': {'p': 0.75, 'r': 0.5, 'f': 0.6}, 'Marca': {'p': 0.8571428571428571, 'r': 0.9574468085106383, 'f': 0.9045226130653266}, 'Modelo': {'p': 0.6491228070175439, 'r': 0.592, 'f': 0.6192468619246863}, 'Potência': {'p': 0.68, 'r': 0.6296296296296297, 'f': 0.6538461538461539}, 'Cor': {'p': 0.8723404255319149, 'r': 0.9111111111111111, 'f': 0.891304347826087}, 'Tipo': {'p': 0.7647058823529411, 'r': 0.9285714285714286, 'f': 0.8387096774193549}, 'Tamanho': {'p': 0.15384615384615385, 'r': 0.4, 'f': 0.2222222222222222}, 'Tensão': {'p': 0.0, 'r': 0.0, 'f': 0.0}}

# %%
# Example text to test the model
doc = nlp("Fone JBL TWS Wave Buds, Auricular, Bluetooth, Preto - JBLWBUDSBLK")

# Print the entities recognized by the model
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Fone 0 4 Categoria
# JBL 5 8 Marca
# TWS 9 12 Conectividade
# Wave Buds 13 22 Modelo
# Auricular 24 33 Tipo
# Bluetooth 35 44 Conectividade
# Preto 46 51 Cor
