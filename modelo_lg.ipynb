# %%
import spacy
import random
import jsonlines
from spacy.training import Example, offsets_to_biluo_tags
from spacy.tokens import DocBin
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
import os

# %%
# Load the SpaCy model
nlp = spacy.load("pt_core_news_lg")

# %%
data = []
with jsonlines.open('dataset.jsonl', 'r') as reader:
    for line in reader:
        data.append(line)

# %%
# Shuffle the dataset to randomize the order
random.shuffle(data)

# %%
# Function to adjust entity spans according to SpaCy's token boundaries
def adjust_entity_spans(doc, entities):
    adjusted_entities = []
    for start, end, label in entities:
        span = doc.char_span(start, end, label=label)
        if span is not None:
            adjusted_entities.append((span.start_char, span.end_char, label))
    return adjusted_entities

# %%
# Convert the dataset to SpaCy format and adjust entity spans
def convert_data_for_spacy(data, nlp):
    spacy_format = []
    for item in data:
        text = item['text']
        doc = nlp.make_doc(text)
        entities = adjust_entity_spans(doc, item['label'])
        spacy_format.append((text, {"entities": entities}))
    return spacy_format

# %%
# Split the data into training and test sets
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# Convert and adjust the training and test data
training_data = convert_data_for_spacy(train_data, nlp)
test_data_spacy = convert_data_for_spacy(test_data, nlp)

# %%
# Add the NER pipeline if not already present
if 'ner' not in nlp.pipe_names:
    ner = nlp.add_pipe('ner')
else:
    ner = nlp.get_pipe('ner')

# Add custom labels to the NER component
for _, annotations in training_data:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

# %%
# Disable other pipeline components during training
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']

# %%
# Fine-tune the model
with nlp.disable_pipes(*unaffected_pipes):
    optimizer = nlp.resume_training()
    for iteration in range(20):  # You can change the number of iterations
        random.shuffle(training_data)
        losses = {}
        for text, annotations in training_data:
            example = Example.from_dict(nlp.make_doc(text), annotations)
            nlp.update([example], drop=0.5, losses=losses)
        print(f"Iteration {iteration + 1}, Losses: {losses}")
# Out:
# Iteration 1, Losses: {'ner': 2551.2318070686133}
# Iteration 2, Losses: {'ner': 1698.2029801005035}
# Iteration 3, Losses: {'ner': 1472.3969145690364}
# Iteration 4, Losses: {'ner': 1375.2522923187178}
# Iteration 5, Losses: {'ner': 1261.1235590317349}
# Iteration 6, Losses: {'ner': 1213.7932695945103}
# Iteration 7, Losses: {'ner': 1183.4964909293676}
# Iteration 8, Losses: {'ner': 1083.0945156105786}
# Iteration 9, Losses: {'ner': 1057.242941091014}
# Iteration 10, Losses: {'ner': 1017.5459326620361}
# Iteration 11, Losses: {'ner': 973.8865147019666}
# Iteration 12, Losses: {'ner': 987.6464811715355}
# Iteration 13, Losses: {'ner': 960.1715961225865}
# Iteration 14, Losses: {'ner': 917.710470902036}
# Iteration 15, Losses: {'ner': 894.5995577302469}
# Iteration 16, Losses: {'ner': 877.945912405704}
# Iteration 17, Losses: {'ner': 870.4786200633469}
# Iteration 18, Losses: {'ner': 846.7784702281651}
# Iteration 19, Losses: {'ner': 816.2684510419485}
# Iteration 20, Losses: {'ner': 784.9000902588084}

# %%
# Save the fine-tuned model
output_dir = "3VA/model_lg"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
nlp.to_disk(output_dir)
print(f"Model saved to {output_dir}")
# Out:
# Model saved to 3VA/model_lg

# %%
# Test the fine-tuned model
nlp = spacy.load(output_dir)

# %%
# Initialize lists for true and predicted labels
true_labels = []
pred_labels = []

for text, annotations in test_data_spacy:
    doc = nlp(text)
    pred_entities = [(ent.start_char, ent.end_char, ent.label_) for ent in doc.ents]
    true_entities = annotations["entities"]

    # Print entities for debugging
    print(text)
    print(doc.ents)
    print("Predicted:", pred_entities)
    print("True:", true_entities)
    print("\n")

    # Create a dictionary to store the predicted and true labels with their spans
    pred_dict = {(start, end): label for start, end, label in pred_entities}
    true_dict = {(start, end): label for start, end, label in true_entities}

    # Union of all spans (keys) from both true and predicted dictionaries
    all_spans = set(pred_dict.keys()).union(set(true_dict.keys()))

    # Compare the labels based on spans
    for span in all_spans:
        true_labels.append(true_dict.get(span, "O"))  # "O" represents no entity in the true labels
        pred_labels.append(pred_dict.get(span, "O"))  # "O" represents no entity in the predicted labels

# Calculate precision, recall, and F1-score
print(classification_report(true_labels, pred_labels))
# Out:
# Mini Torre Neon 2 Led Rgb 250w Bt/Sd/Fm/Aux/Tws Multilaser – SP400
# (Mini Torre, Neon 2, Led Rgb, 250w, Bt/Sd/Fm/Aux/Tws, Multilaser, SP400)
# Predicted: [(0, 10, 'Categoria'), (11, 17, 'Modelo'), (18, 25, 'Caracteristicas'), (26, 30, 'Potência'), (31, 47, 'Conectividade'), (48, 58, 'Marca'), (61, 66, 'Modelo')]
# True: [(0, 10, 'Categoria'), (16, 25, 'Caracteristicas'), (26, 30, 'Potência'), (31, 47, 'Conectividade'), (48, 58, 'Marca'), (61, 66, 'Modelo')]
#
#
# Fone De Ouvido Multilaser Monster High P2 - PH105
# (Fone De Ouvido, Multilaser, Monster High P2, PH105)
# Predicted: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 41, 'Modelo'), (44, 49, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 38, 'Modelo'), (39, 41, 'Tipo'), (44, 49, 'Modelo')]
#
#
# Fone JBL TWS Wave Buds, Auricular, Bluetooth, Preto - JBLWBUDSBLK
# (Fone JBL, TWS Wave Buds, Auricular, Bluetooth, Preto)
# Predicted: [(0, 8, 'Categoria'), (9, 22, 'Modelo'), (24, 33, 'Tipo'), (35, 44, 'Conectividade'), (46, 51, 'Cor')]
# True: [(0, 4, 'Categoria'), (5, 8, 'Marca'), (9, 12, 'Conectividade'), (13, 22, 'Modelo'), (24, 33, 'Tipo'), (35, 44, 'Conectividade'), (46, 51, 'Cor')]
#
#
# Fone de Ouvido Auricular JBL Bluetooth 300 Wave TWS, Branco - JBLW300TWSWHT
# (Fone de Ouvido, Auricular, JBL, Bluetooth, Branco, JBLW300TWSWHT)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (39, 51, 'Potência'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
#
#
# Headphone JBL Tune 600 BT NC, Bluetooth, Preto
# (Headphone, JBL, Tune 600, BT NC, Bluetooth, Preto)
# Predicted: [(0, 9, 'Categoria'), (10, 13, 'Marca'), (14, 22, 'Modelo'), (23, 28, 'Conectividade'), (30, 39, 'Conectividade'), (41, 46, 'Cor')]
# True: [(0, 9, 'Categoria'), (10, 13, 'Marca'), (14, 28, 'Modelo'), (30, 39, 'Conectividade'), (41, 46, 'Cor')]
#
#
# Fone de Ouvido Bluetooth JBL Tune 510BT Preto JBLT510BTBLK
# (Fone de Ouvido, Bluetooth, JBL, Tune 510BT, Preto, JBLT510BTBLK)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 28, 'Marca'), (29, 39, 'Modelo'), (40, 45, 'Cor'), (46, 58, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 28, 'Marca'), (29, 39, 'Modelo'), (40, 45, 'Cor'), (46, 58, 'Modelo')]
#
#
# Caixa de Som Portátil JBL Charge 4, Bluetooth, 30W, À Prova D´Água, Verde - JBLCHARGE4GRN
# (Caixa de Som, Portátil, JBL, Charge 4, Bluetooth, 30W, À Prova D´Água, Verde, JBLCHARGE4GRN)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 34, 'Modelo'), (36, 45, 'Conectividade'), (47, 50, 'Potência'), (52, 66, 'Caracteristicas'), (68, 73, 'Cor'), (76, 89, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 34, 'Modelo'), (36, 45, 'Conectividade'), (47, 50, 'Potência'), (52, 66, 'Caracteristicas'), (68, 73, 'Cor'), (76, 89, 'Modelo')]
#
#
# Fone Com Microfone Usb Preto Microsoft - JUG00013
# (Fone, Com Microfone, Usb, Preto, Microsoft, JUG00013)
# Predicted: [(0, 4, 'Categoria'), (5, 18, 'Caracteristicas'), (19, 22, 'Conectividade'), (23, 28, 'Cor'), (29, 38, 'Marca'), (41, 49, 'Modelo')]
# True: [(0, 4, 'Categoria'), (5, 18, 'Item adicional'), (19, 22, 'Conectividade'), (23, 28, 'Cor'), (29, 38, 'Marca'), (41, 49, 'Modelo')]
#
#
# Headset Gamer Corsair HS70 Wireless Carbono, 7.1 Surround, Branco - CA-9011177-NA
# (Headset, Gamer, Corsair, HS70, Wireless, Carbono, 7.1 Surround, Branco)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 21, 'Marca'), (22, 26, 'Modelo'), (27, 35, 'Conectividade'), (36, 57, 'Caracteristicas'), (59, 65, 'Cor')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 21, 'Marca'), (22, 26, 'Modelo'), (27, 35, 'Conectividade'), (36, 43, 'Caracteristicas'), (45, 57, 'Caracteristicas'), (59, 65, 'Cor')]
#
#
# Toca-Disco ObaWave Conversor de Vinil Obabox - OB007
# (Toca-Disco ObaWave, Conversor de Vinil, OB007)
# Predicted: [(0, 18, 'Categoria'), (19, 37, 'Caracteristicas'), (47, 52, 'Modelo')]
# True: [(0, 10, 'Categoria'), (11, 37, 'Modelo'), (38, 44, 'Marca'), (47, 52, 'Modelo')]
#
#
# Fone De Ouvido Multilaser Standard P2 3.5mm Preto - PH006
# (Fone De Ouvido, Multilaser, Standard P2 3.5mm, Preto, PH006)
# Predicted: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 43, 'Modelo'), (44, 49, 'Cor'), (52, 57, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 34, 'Modelo'), (35, 37, 'Conectividade'), (38, 43, 'Tamanho'), (44, 49, 'Cor'), (52, 57, 'Modelo')]
#
#
# Caixa de Som Xplode 3 300W Bluetooth Pulse - SP606
# (Caixa de Som, Xplode 3, 300W, Bluetooth, Pulse, SP606)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Modelo'), (22, 26, 'Potência'), (27, 36, 'Conectividade'), (37, 42, 'Marca'), (45, 50, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Modelo'), (22, 26, 'Potência'), (27, 36, 'Conectividade'), (37, 42, 'Marca'), (45, 50, 'Modelo')]
#
#
# Caixa De Som Pulse Mini Bluetooth/Sd/P2 10W Rms Roxo E Rosa - SP239
# (Caixa De Som, Pulse, Mini, Bluetooth/Sd/P2, 10W Rms, Roxo E, Rosa, SP239)
# Predicted: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 23, 'Modelo'), (24, 39, 'Conectividade'), (40, 47, 'Potência'), (48, 54, 'Caracteristicas'), (55, 59, 'Cor'), (62, 67, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 23, 'Modelo'), (24, 39, 'Conectividade'), (40, 47, 'Potência'), (48, 52, 'Cor'), (55, 59, 'Cor'), (62, 67, 'Modelo')]
#
#
# Receptor De Música Bluetooth Multilaser 10Mts P2 - RE053
# (Receptor De Música, Bluetooth, Multilaser, RE053)
# Predicted: [(0, 18, 'Categoria'), (19, 28, 'Conectividade'), (29, 39, 'Marca'), (51, 56, 'Modelo')]
# True: [(0, 18, 'Categoria'), (19, 28, 'Conectividade'), (29, 39, 'Marca'), (40, 48, 'Potência'), (51, 56, 'Modelo')]
#
#
# Soundbar 2.0 Gamer 15w Rms Led - SP953
# (Soundbar, Gamer, 15w, SP953)
# Predicted: [(0, 8, 'Categoria'), (13, 18, 'Caracteristicas'), (19, 22, 'Potência'), (33, 38, 'Modelo')]
# True: [(0, 8, 'Categoria'), (9, 18, 'Modelo'), (19, 26, 'Potência'), (27, 30, 'Caracteristicas'), (33, 38, 'Modelo')]
#
#
# Fone De Ouvido Silicone Earhook Pulse Preto/Azul - PH220
# (Fone De Ouvido, Silicone, Earhook, Pulse, Preto/Azul)
# Predicted: [(0, 14, 'Categoria'), (15, 23, 'Caracteristicas'), (24, 31, 'Caracteristicas'), (32, 37, 'Marca'), (38, 48, 'Cor')]
# True: [(0, 14, 'Categoria'), (15, 23, 'Caracteristicas'), (24, 31, 'Modelo'), (32, 37, 'Marca'), (38, 48, 'Cor'), (51, 56, 'Modelo')]
#
#
# Headset Gamer HyperX 7.1 Cloud II KHX-HSCP-RD Preto e Vermelho
# (Headset, Gamer, HyperX, Cloud II KHX-HSCP-RD, Preto e Vermelho)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (25, 45, 'Modelo'), (46, 62, 'Cor')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 20, 'Marca'), (21, 45, 'Modelo'), (46, 51, 'Cor'), (54, 62, 'Cor')]
#
#
# Pulse Torre Double 12 1600W - SP360
# (Pulse, Torre Double 12, 1600W, SP360)
# Predicted: [(0, 5, 'Marca'), (6, 21, 'Modelo'), (22, 27, 'Potência'), (30, 35, 'Modelo')]
# True: [(0, 5, 'Marca'), (6, 11, 'Tipo'), (12, 18, 'Modelo'), (19, 21, 'Tamanho'), (22, 29, 'Potência'), (30, 35, 'Modelo')]
#
#
# Caixa de Som Acústica Multilaser SP341 SUNNY 700W BT/AUX/SD/USB/FM/LED
# (Caixa de Som, Acústica, Multilaser, SP341, SUNNY, 700W, BT/AUX/SD/USB/FM/LED)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Caracteristicas'), (22, 32, 'Marca'), (33, 38, 'Modelo'), (39, 44, 'Conectividade'), (45, 49, 'Potência'), (50, 70, 'Conectividade')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Caracteristicas'), (22, 32, 'Marca'), (33, 38, 'Modelo'), (39, 44, 'Modelo'), (45, 49, 'Potência'), (50, 52, 'Conectividade'), (53, 56, 'Conectividade'), (57, 59, 'Conectividade'), (60, 63, 'Conectividade'), (64, 66, 'Conectividade'), (67, 70, 'Caracteristicas')]
#
#
# Caixa De Som Multilaser 2.1 Preto E Grafite Usb - SP166
# (Caixa De Som, Multilaser, Preto E Grafite, SP166)
# Predicted: [(0, 12, 'Categoria'), (13, 23, 'Marca'), (28, 43, 'Cor'), (50, 55, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 23, 'Marca'), (24, 27, 'Modelo'), (28, 43, 'Cor'), (44, 47, 'Conectividade'), (50, 55, 'Modelo')]
#
#
# Boombox Multilaser Bluetooth 20w - SP338
# (Boombox, Multilaser, Bluetooth, SP338)
# Predicted: [(0, 7, 'Categoria'), (8, 18, 'Marca'), (19, 28, 'Conectividade'), (35, 40, 'Modelo')]
# True: [(0, 7, 'Modelo'), (8, 18, 'Marca'), (19, 28, 'Conectividade'), (29, 34, 'Potência'), (35, 40, 'Modelo')]
#
#
# Caixa de Som Frahm Sb215 Bluetooth Portátil - Preta
# (Caixa de Som, Frahm, Sb215, Bluetooth, Portátil, Preta)
# Predicted: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 24, 'Modelo'), (25, 34, 'Conectividade'), (35, 43, 'Tipo'), (46, 51, 'Cor')]
# True: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 24, 'Modelo'), (35, 43, 'Tipo'), (46, 51, 'Cor')]
#
#
# Fone de Ouvido Auricular JBL Bluetooth 300 Wave TWS, Branco - JBLW300TWSWHT
# (Fone de Ouvido, Auricular, JBL, Bluetooth, Branco, JBLW300TWSWHT)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (39, 51, 'Potência'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
#
#
# Caixa Bluetooth Exbom Drum Speaker 3w Cores Sortidas - Cs-M26bt
# (Caixa, Bluetooth, Exbom, Drum Speaker, 3w, Sortidas, Cs-M26bt)
# Predicted: [(0, 5, 'Categoria'), (6, 15, 'Conectividade'), (16, 21, 'Marca'), (22, 34, 'Modelo'), (35, 37, 'Potência'), (44, 52, 'Modelo'), (55, 63, 'Modelo')]
# True: [(0, 5, 'Categoria'), (6, 15, 'Conectividade'), (16, 21, 'Marca'), (22, 34, 'Categoria'), (35, 37, 'Potência'), (55, 63, 'Modelo')]
#
#
# Sound bar LG SL9YG Bluetooth / HDMI / Wi-Fi áudio (Hi-Res) 96 kHz 500W RMS
# (Sound bar, LG, SL9YG, Bluetooth / HDMI / Wi-Fi áudio, 96 kHz, 500W RMS)
# Predicted: [(0, 9, 'Categoria'), (10, 12, 'Marca'), (13, 18, 'Modelo'), (19, 49, 'Conectividade'), (59, 65, 'Tamanho'), (66, 74, 'Potência')]
# True: [(0, 9, 'Categoria'), (10, 12, 'Marca'), (13, 18, 'Modelo'), (19, 28, 'Conectividade'), (31, 35, 'Conectividade'), (38, 43, 'Conectividade'), (59, 65, 'Potência'), (66, 74, 'Potência')]
#
#
# Caixa De Som Multilaser Mini Aux. 8W Preto - SP277
# (Caixa De Som, Multilaser, Mini Aux., 8W, Preto, SP277)
# Predicted: [(0, 12, 'Categoria'), (13, 23, 'Marca'), (24, 33, 'Modelo'), (34, 36, 'Potência'), (37, 42, 'Cor'), (45, 50, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 23, 'Marca'), (24, 28, 'Modelo'), (34, 36, 'Potência'), (37, 42, 'Cor'), (45, 50, 'Modelo')]
#
#
# Headphone JBL Tune 600 BT NC, Bluetooth, Preto
# (Headphone, JBL, Tune 600, BT NC, Bluetooth, Preto)
# Predicted: [(0, 9, 'Categoria'), (10, 13, 'Marca'), (14, 22, 'Modelo'), (23, 28, 'Conectividade'), (30, 39, 'Conectividade'), (41, 46, 'Cor')]
# True: [(0, 9, 'Categoria'), (10, 13, 'Marca'), (14, 28, 'Modelo'), (30, 39, 'Conectividade'), (41, 46, 'Cor')]
#
#
# Headphone JBL Bluetooth 4.0 Com Limite de Volume Azul/Laranja Jr 300BT - JBLJR300BTUNO
# (Headphone, JBL, Bluetooth 4.0 Com Limite de Volume, Azul/Laranja, Jr 300BT, JBLJR300BTUNO)
# Predicted: [(0, 9, 'Categoria'), (10, 13, 'Marca'), (14, 48, 'Conectividade'), (49, 61, 'Cor'), (62, 70, 'Modelo'), (73, 86, 'Modelo')]
# True: [(0, 9, 'Categoria'), (10, 13, 'Marca'), (14, 27, 'Conectividade'), (28, 48, 'Caracteristicas'), (49, 61, 'Cor'), (62, 70, 'Modelo')]
#
#
# Fone de Ouvido Bluetooth JBL Tune 510BT Preto JBLT510BTBLK
# (Fone de Ouvido, Bluetooth, JBL, Tune 510BT, Preto, JBLT510BTBLK)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 28, 'Marca'), (29, 39, 'Modelo'), (40, 45, 'Cor'), (46, 58, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 28, 'Marca'), (29, 39, 'Modelo'), (40, 45, 'Cor'), (46, 58, 'Modelo')]
#
#
# Caixa De Som Monster High Speaker Multikids- SP170
# (Caixa De Som, Monster High, Speaker, SP170)
# Predicted: [(0, 12, 'Categoria'), (13, 25, 'Modelo'), (26, 33, 'Categoria'), (45, 50, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 25, 'Modelo'), (26, 33, 'Categoria'), (45, 50, 'Modelo')]
#
#
# Caixa de Som Gamer Warrior Odysseus P2 2.1 50W RMS Com Subwoofer - SP266
# (Caixa de Som, Gamer, Warrior Odysseus, P2 2.1, 50W RMS, Com Subwoofer, SP266)
# Predicted: [(0, 12, 'Categoria'), (13, 18, 'Caracteristicas'), (19, 35, 'Modelo'), (36, 42, 'Conectividade'), (43, 50, 'Potência'), (51, 64, 'Item adicional'), (67, 72, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 18, 'Caracteristicas'), (36, 38, 'Conectividade'), (39, 42, 'Modelo'), (43, 50, 'Potência'), (51, 64, 'Item adicional'), (67, 72, 'Modelo')]
#
#
# Caixa Ativa 12 Pol. 160W - SP369
# (Caixa Ativa, 12 Pol, 160W, SP369)
# Predicted: [(0, 11, 'Categoria'), (12, 18, 'Tamanho'), (20, 24, 'Potência'), (27, 32, 'Modelo')]
# True: [(0, 11, 'Categoria'), (12, 18, 'Tamanho'), (20, 24, 'Potência'), (27, 32, 'Modelo')]
#
#
# Fone de Ouvido Auricular JBL Bluetooth 300 Wave TWS, Branco - JBLW300TWSWHT
# (Fone de Ouvido, Auricular, JBL, Bluetooth, Branco, JBLW300TWSWHT)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 38, 'Conectividade'), (39, 47, 'Modelo'), (48, 51, 'Conectividade'), (53, 59, 'Cor'), (62, 75, 'Modelo')]
#
#
# Caixa Acústica Philco PCX16000 - Bivolt
# (Caixa Acústica, Philco, PCX16000 -, Bivolt)
# Predicted: [(0, 14, 'Categoria'), (15, 21, 'Marca'), (22, 32, 'Modelo'), (33, 39, 'Tensão')]
# True: [(0, 14, 'Categoria'), (15, 21, 'Marca'), (22, 30, 'Modelo'), (33, 39, 'Tensão')]
#
#
# Caixa de Som Portátil JBL GO 3 Bluetooth 5.1 À Prova D'água e Poeira IP67 Vermelho
# (Caixa de Som, Portátil, JBL, GO 3, Bluetooth 5.1, À Prova D'água e Poeira, IP67, Vermelho)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 30, 'Modelo'), (31, 44, 'Conectividade'), (45, 68, 'Caracteristicas'), (69, 73, 'Caracteristicas'), (74, 82, 'Cor')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 30, 'Modelo'), (31, 44, 'Conectividade'), (45, 68, 'Caracteristicas'), (69, 73, 'Modelo'), (74, 82, 'Cor')]
#
#
# Caixa de Som JBL Go 2 Bluetooth, À Prova D´água, 3.1W, Verde Claro
# (Caixa de Som, JBL, Go 2, Bluetooth, À Prova D´água, 3.1W, Verde, Claro)
# Predicted: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 21, 'Modelo'), (22, 31, 'Conectividade'), (33, 47, 'Caracteristicas'), (49, 53, 'Potência'), (55, 60, 'Cor'), (61, 66, 'Cor')]
# True: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 21, 'Modelo'), (22, 31, 'Conectividade'), (33, 47, 'Caracteristicas'), (49, 53, 'Potência'), (55, 66, 'Cor')]
#
#
# Headset Office P3 3.5mm Preto Controle de Volume Microfone C/ Redução de Ruído - PH373
# (Headset, Office P3 3.5mm, Preto, Microfone, PH373)
# Predicted: [(0, 7, 'Categoria'), (8, 23, 'Modelo'), (24, 29, 'Cor'), (49, 58, 'Caracteristicas'), (81, 86, 'Modelo')]
# True: [(0, 7, 'Categoria'), (8, 14, 'Marca'), (15, 17, 'Modelo'), (18, 23, 'Tamanho'), (24, 29, 'Cor'), (30, 78, 'Caracteristicas')]
#
#
# Fone de Ouvido Auricular Bluetooth JBL Tune 215BT Pure Bass Hands-Free com Microfone, Preto-JBLT215BTBLK
# (Fone de Ouvido, Auricular, Bluetooth, JBL, Tune 215BT Pure Bass Hands-Free, com Microfone)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 34, 'Conectividade'), (35, 38, 'Marca'), (39, 70, 'Modelo'), (71, 84, 'Caracteristicas')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 34, 'Conectividade'), (35, 38, 'Marca'), (39, 49, 'Modelo'), (50, 59, 'Caracteristicas'), (60, 70, 'Caracteristicas'), (71, 84, 'Caracteristicas')]
#
#
# Caixa de Som portátil JBL Partybox 100 Bluetooth USB
# (Caixa de Som, portátil, JBL, Partybox 100, Bluetooth, USB)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 38, 'Modelo'), (39, 48, 'Conectividade'), (49, 52, 'Conectividade')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 38, 'Modelo'), (39, 48, 'Conectividade'), (49, 52, 'Conectividade')]
#
#
# Caixa de Som Portátil JBL Charge 4, Bluetooth, 30W, À Prova D´Água, Verde - JBLCHARGE4GRN
# (Caixa de Som, Portátil, JBL, Charge 4, Bluetooth, 30W, À Prova D´Água, Verde, JBLCHARGE4GRN)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 34, 'Modelo'), (36, 45, 'Conectividade'), (47, 50, 'Potência'), (52, 66, 'Caracteristicas'), (68, 73, 'Cor'), (76, 89, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 34, 'Modelo'), (36, 45, 'Conectividade'), (47, 50, 'Potência'), (52, 66, 'Caracteristicas'), (68, 73, 'Cor'), (76, 89, 'Modelo')]
#
#
# Fone De Ouvido Multilaser Headphone Vibe Design Retro P2 Preto - PH053
# (Fone De Ouvido, Multilaser, Headphone, Vibe, Design Retro, P2, Preto, PH053)
# Predicted: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 35, 'Tipo'), (36, 40, 'Modelo'), (41, 53, 'Caracteristicas'), (54, 56, 'Conectividade'), (57, 62, 'Cor'), (65, 70, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 35, 'Tipo'), (36, 40, 'Modelo'), (41, 53, 'Caracteristicas'), (54, 56, 'Conectividade'), (57, 62, 'Cor')]
#
#
# Caixa De Som 10W Rms Bluetooth Multilaser- SP286
# (Caixa De Som, 10W, Bluetooth, Multilaser- SP286)
# Predicted: [(0, 12, 'Categoria'), (13, 16, 'Potência'), (21, 30, 'Conectividade'), (31, 48, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 20, 'Potência'), (21, 30, 'Conectividade'), (43, 48, 'Modelo')]
#
#
# Caixa de Som Portátil JBL Clip 3 com Bluetooth Branco
# (Caixa de Som, Portátil, JBL, Clip 3, Bluetooth, Branco)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 32, 'Modelo'), (37, 46, 'Conectividade'), (47, 53, 'Cor')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 32, 'Modelo'), (37, 46, 'Conectividade'), (47, 53, 'Cor')]
#
#
# Boombox / Som Portátil Philco PB140, MP3, MP4, FM, Branco - Bivolt
# (Boombox / Som, Portátil, Philco, PB140, MP3, MP4, Branco, Bivolt)
# Predicted: [(0, 13, 'Modelo'), (14, 22, 'Tipo'), (23, 29, 'Marca'), (30, 35, 'Modelo'), (37, 40, 'Conectividade'), (42, 45, 'Conectividade'), (51, 57, 'Cor'), (60, 66, 'Tensão')]
# True: [(23, 29, 'Marca'), (30, 50, 'Conectividade'), (51, 57, 'Cor'), (60, 66, 'Marca')]
#
#
# Fone de Ouvido Xiaomi Mi True Bluetooth Wireless Earbuds Basic S, Preto- XM522PRE
# (Fone de Ouvido, Xiaomi, Mi True, Bluetooth, Wireless, XM522PRE)
# Predicted: [(0, 14, 'Categoria'), (15, 21, 'Marca'), (22, 29, 'Modelo'), (30, 39, 'Conectividade'), (40, 48, 'Conectividade'), (73, 81, 'Marca')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Marca'), (25, 29, 'Modelo'), (30, 39, 'Conectividade'), (40, 48, 'Conectividade'), (49, 62, 'Modelo'), (66, 81, 'Caracteristicas')]
#
#
# Caixa De Som Resistente A Água Com Bluetooth Preto Pulse - SP245
# (Caixa De Som, A Água, Bluetooth, Preto, Pulse, SP245)
# Predicted: [(0, 12, 'Categoria'), (24, 30, 'Caracteristicas'), (35, 44, 'Conectividade'), (45, 50, 'Cor'), (51, 56, 'Marca'), (59, 64, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 30, 'Caracteristicas'), (35, 44, 'Conectividade'), (45, 50, 'Cor'), (51, 56, 'Marca'), (59, 64, 'Modelo')]
#
#
# Fone Earhook In-Ear Sport Metallic Áudio Bluetooth Amarelo Pulse - PH254
# (Fone Earhook In-Ear, Sport Metallic Áudio, Bluetooth, Amarelo, Pulse, PH254)
# Predicted: [(0, 19, 'Categoria'), (20, 40, 'Modelo'), (41, 50, 'Conectividade'), (51, 58, 'Cor'), (59, 64, 'Marca'), (67, 72, 'Modelo')]
# True: [(0, 4, 'Categoria'), (5, 40, 'Modelo'), (41, 50, 'Conectividade'), (51, 58, 'Cor'), (59, 64, 'Marca'), (67, 72, 'Modelo')]
#
#
# Headset Gamer Logitech G PRO Stereo Drivers de 50 mm Preto - 981-000811
# (Headset, Gamer, Logitech, G PRO, Stereo, Drivers de 50 mm, Preto)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 22, 'Marca'), (23, 28, 'Modelo'), (29, 35, 'Caracteristicas'), (36, 52, 'Caracteristicas'), (53, 58, 'Cor')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 22, 'Marca'), (23, 28, 'Modelo'), (29, 35, 'Caracteristicas'), (36, 52, 'Caracteristicas'), (53, 58, 'Cor')]
#
#
# Headphone JBL Bluetooth 4.0 Com Limite de Volume Azul/Laranja Jr 300BT - JBLJR300BTUNO
# (Headphone, JBL, Bluetooth 4.0 Com Limite de Volume, Azul/Laranja, Jr 300BT, JBLJR300BTUNO)
# Predicted: [(0, 9, 'Categoria'), (10, 13, 'Marca'), (14, 48, 'Conectividade'), (49, 61, 'Cor'), (62, 70, 'Modelo'), (73, 86, 'Modelo')]
# True: [(0, 9, 'Categoria'), (10, 13, 'Marca'), (14, 27, 'Conectividade'), (28, 48, 'Caracteristicas'), (49, 61, 'Cor'), (62, 70, 'Modelo')]
#
#
# Earphone TWS Pulse Drop PRETO Pulse Sound - PH345
# (Earphone, TWS, Pulse, PRETO, Pulse, PH345)
# Predicted: [(0, 8, 'Categoria'), (9, 12, 'Conectividade'), (13, 18, 'Marca'), (24, 29, 'Cor'), (30, 35, 'Marca'), (44, 49, 'Modelo')]
# True: [(0, 8, 'Categoria'), (9, 12, 'Conectividade'), (13, 18, 'Marca'), (19, 23, 'Modelo'), (24, 29, 'Cor'), (30, 35, 'Marca'), (36, 49, 'Modelo')]
#
#
# Caixa de Som Boombox Multilaser 20W AUX/USB/FM - SP337
# (Caixa de Som, Boombox, Multilaser, 20W, AUX/USB/FM, SP337)
# Predicted: [(0, 12, 'Categoria'), (13, 20, 'Marca'), (21, 31, 'Marca'), (32, 35, 'Potência'), (36, 46, 'Conectividade'), (49, 54, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 20, 'Modelo'), (21, 31, 'Marca'), (32, 35, 'Potência'), (36, 39, 'Conectividade'), (40, 46, 'Conectividade'), (49, 54, 'Modelo')]
#
#
# Caixa De Som Usb 2.0 5w Voxcube Vc-878 Exbom
# (Caixa De Som, Usb 2.0 5w Voxcube Vc-878 Exbom)
# Predicted: [(0, 12, 'Categoria'), (13, 44, 'Conectividade')]
# True: [(0, 12, 'Categoria'), (13, 20, 'Conectividade'), (21, 23, 'Potência'), (24, 38, 'Modelo'), (39, 44, 'Marca')]
#
#
# Fone de Ouvido Auricular JBL Wave 200TWS, Azul - JBLW200TWSBLU
# (Fone de Ouvido, Auricular, JBL, Wave 200TWS, Azul, JBLW200TWSBLU)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 40, 'Modelo'), (42, 46, 'Cor'), (49, 62, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 40, 'Modelo'), (42, 46, 'Cor'), (49, 62, 'Modelo')]
#
#
# Fone De Ouvido Bluetooth Awei A900bl
# (Fone De Ouvido, Bluetooth, Awei, A900bl)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 29, 'Marca'), (30, 36, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 29, 'Marca'), (30, 36, 'Modelo')]
#
#
# Caixa de Som Amvox ACA-150 Usb, Card, Aux, Bluetooth, Radio FM, 100W Preto - Bivolt
# (Caixa de Som, Amvox, ACA-150 Usb, Bluetooth, Radio FM, 100W, Preto, Bivolt)
# Predicted: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 30, 'Modelo'), (43, 52, 'Conectividade'), (54, 62, 'Caracteristicas'), (64, 68, 'Potência'), (69, 74, 'Cor'), (77, 83, 'Tensão')]
# True: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 26, 'Modelo'), (27, 30, 'Conectividade'), (32, 36, 'Conectividade'), (38, 41, 'Conectividade'), (43, 52, 'Conectividade'), (54, 62, 'Caracteristicas'), (64, 68, 'Potência'), (69, 74, 'Cor'), (77, 83, 'Marca')]
#
#
# Caixa de Som ObaSound Pool Obabox - OB008
# (Caixa de Som, ObaSound Pool Obabox - OB008)
# Predicted: [(0, 12, 'Categoria'), (13, 41, 'Conectividade')]
# True: [(0, 12, 'Categoria'), (13, 26, 'Modelo'), (27, 33, 'Marca')]
#
#
# Fone de Ouvido Intra-Auricular Bluetooth JBL Tune 125BT, Preto-JBLT125BTBLK
# (Fone de Ouvido, Intra-Auricular, Bluetooth, JBL)
# Predicted: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca')]
# True: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
#
#
# Fone de Ouvido Intra-Auricular Bluetooth JBL Tune 125BT, Preto-JBLT125BTBLK
# (Fone de Ouvido, Intra-Auricular, Bluetooth, JBL)
# Predicted: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca')]
# True: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
#
#
# Caixa de Som Portátil JBL GO 3 Bluetooth 5.1 À Prova D'água e Poeira IP67 Preto
# (Caixa de Som, Portátil, JBL, GO 3, Bluetooth 5.1, À Prova D'água e Poeira, IP67, Preto)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 30, 'Modelo'), (31, 44, 'Conectividade'), (45, 68, 'Caracteristicas'), (69, 73, 'Caracteristicas'), (74, 79, 'Cor')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 30, 'Modelo'), (31, 44, 'Conectividade'), (45, 68, 'Caracteristicas'), (69, 73, 'Caracteristicas'), (74, 79, 'Cor')]
#
#
# Fone de Ouvido Bluetooth Samsung Galaxy Buds Live Branco
# (Fone de Ouvido, Bluetooth, Samsung, Galaxy Buds Live, Branco)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 32, 'Marca'), (33, 49, 'Modelo'), (50, 56, 'Cor')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 32, 'Marca'), (33, 49, 'Modelo'), (50, 56, 'Cor')]
#
#
# Caixa de Som JBL PartyBox 310 Bluetooth Portátil - Amplificada USB com Tweeter
# (Caixa de Som, JBL, PartyBox 310, Bluetooth, Portátil, Amplificada, USB, com Tweeter)
# Predicted: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 29, 'Modelo'), (30, 39, 'Conectividade'), (40, 48, 'Tipo'), (51, 62, 'Potência'), (63, 66, 'Conectividade'), (67, 78, 'Caracteristicas')]
# True: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 29, 'Modelo'), (30, 39, 'Conectividade'), (40, 48, 'Tipo'), (51, 62, 'Potência'), (63, 66, 'Conectividade'), (67, 78, 'Caracteristicas')]
#
#
# Caixa de Som JBL Wind 2 Suporte para Motos e Bicicletas Bluetooth À Prova D'água - JBLWIND2BLK
# (Caixa de Som, JBL, Wind 2, Suporte para Motos e Bicicletas, Bluetooth, À Prova D'água)
# Predicted: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 23, 'Modelo'), (24, 55, 'Caracteristicas'), (56, 65, 'Conectividade'), (66, 80, 'Caracteristicas')]
# True: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 23, 'Modelo'), (24, 55, 'Caracteristicas'), (56, 65, 'Conectividade'), (66, 80, 'Caracteristicas')]
#
#
# Headset Office GT Basic com Cabo de 1.8m | GT
# (Headset, Office GT Basic, Cabo de 1.8m, GT)
# Predicted: [(0, 7, 'Categoria'), (8, 23, 'Modelo'), (28, 40, 'Tamanho'), (43, 45, 'Marca')]
# True: [(0, 7, 'Categoria'), (8, 23, 'Modelo'), (24, 40, 'Caracteristicas'), (43, 45, 'Marca')]
#
#
# Headset HyperX CloudX Chat Xbox, Drivers 40mm, Preto - HX-HSCCHX-BK/WW
# (Headset, HyperX, CloudX, Xbox, Drivers 40mm, Preto, HX-HSCCHX-BK/WW)
# Predicted: [(0, 7, 'Categoria'), (8, 14, 'Marca'), (15, 21, 'Modelo'), (27, 31, 'Conectividade'), (33, 45, 'Caracteristicas'), (47, 52, 'Cor'), (55, 70, 'Modelo')]
# True: [(0, 7, 'Categoria'), (8, 14, 'Marca'), (15, 21, 'Modelo'), (27, 31, 'Conectividade'), (33, 45, 'Caracteristicas'), (47, 52, 'Cor')]
#
#
# Caixa de Som portátil JBL Partybox 100 Bluetooth USB
# (Caixa de Som, portátil, JBL, Partybox 100, Bluetooth, USB)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 38, 'Modelo'), (39, 48, 'Conectividade'), (49, 52, 'Conectividade')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 38, 'Modelo'), (39, 48, 'Conectividade'), (49, 52, 'Conectividade')]
#
#
# Fone de Ouvido Vibe Vermelho Multilaser - PH325
# (Fone de Ouvido, Vibe, Vermelho, Multilaser, PH325)
# Predicted: [(0, 14, 'Categoria'), (15, 19, 'Modelo'), (20, 28, 'Cor'), (29, 39, 'Marca'), (42, 47, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 19, 'Modelo'), (20, 28, 'Cor'), (29, 39, 'Marca'), (42, 47, 'Modelo')]
#
#
# Tela De Projeção Elétrica 2,03X1,52M 100 Polegadas Com Controle Remoto 220V - AC355
# (220V, AC355)
# Predicted: [(71, 75, 'Potência'), (78, 83, 'Modelo')]
# True: [(0, 16, 'Categoria'), (26, 36, 'Tamanho'), (37, 50, 'Tamanho'), (51, 70, 'Caracteristicas'), (71, 75, 'Tensão'), (78, 83, 'Modelo')]
#
#
# Caixa de Som 6W RMS GT Sound 2.0 - Preto/Azul | GT
# (Caixa de Som, 6W RMS, GT, Preto/Azul, GT)
# Predicted: [(0, 12, 'Categoria'), (13, 19, 'Potência'), (20, 22, 'Marca'), (35, 45, 'Cor'), (48, 50, 'Marca')]
# True: [(0, 12, 'Categoria'), (13, 19, 'Potência'), (20, 22, 'Marca'), (23, 32, 'Modelo'), (48, 50, 'Marca')]
#
#
# Caixa de Som JBL Link 20, Bluetooth, 20 watts, À prova d’água, Preta
# (Caixa de Som, JBL, Link 20, Bluetooth, 20 watts, À prova d’água, Preta)
# Predicted: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 24, 'Modelo'), (26, 35, 'Conectividade'), (37, 45, 'Potência'), (47, 61, 'Caracteristicas'), (63, 68, 'Cor')]
# True: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 24, 'Modelo'), (26, 35, 'Conectividade'), (37, 45, 'Potência'), (47, 61, 'Caracteristicas'), (63, 68, 'Cor')]
#
#
# Caixa Amplificadora Multilaser Bluetooth 400W RMS Com Microfone sem Fio Preto – SP331
# (Caixa Amplificadora, Multilaser, Bluetooth, 400W RMS, Com Microfone sem Fio, Preto, SP331)
# Predicted: [(0, 19, 'Categoria'), (20, 30, 'Marca'), (31, 40, 'Conectividade'), (41, 49, 'Potência'), (50, 71, 'Item adicional'), (72, 77, 'Cor'), (80, 85, 'Modelo')]
# True: [(0, 19, 'Categoria'), (20, 30, 'Marca'), (31, 40, 'Conectividade'), (41, 49, 'Potência'), (50, 71, 'Item adicional'), (72, 77, 'Cor'), (80, 85, 'Modelo')]
#
#
# Earphone TWS Touch Pulse Preto – PH320
# (Earphone, TWS Touch, Pulse, Preto, PH320)
# Predicted: [(0, 8, 'Categoria'), (9, 18, 'Conectividade'), (19, 24, 'Marca'), (25, 30, 'Cor'), (33, 38, 'Modelo')]
# True: [(0, 8, 'Categoria'), (9, 18, 'Modelo'), (19, 24, 'Marca'), (25, 30, 'Cor'), (33, 38, 'Modelo')]
#
#
# Fone de Ouvido Intra-Auricular Bluetooth JBL Tune 125BT, Preto-JBLT125BTBLK
# (Fone de Ouvido, Intra-Auricular, Bluetooth, JBL)
# Predicted: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca')]
# True: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
#
#
# Caixa de Som Portátil JBL Clip 3 com Bluetooth Squad Camuflada
# (Caixa de Som, Portátil, JBL, Clip 3, Bluetooth Squad Camuflada)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 32, 'Modelo'), (37, 62, 'Conectividade')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 32, 'Modelo'), (37, 46, 'Conectividade'), (53, 62, 'Cor')]
#
#
# Caixa de Som ObaSound Party Obabox - OB009
# (Caixa de Som, ObaSound, Party Obabox, OB009)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Conectividade'), (22, 34, 'Modelo'), (37, 42, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 27, 'Modelo'), (28, 34, 'Marca'), (37, 42, 'Modelo')]
#
#
# Fone de Ouvido Intra-Auricular Bluetooth JBL Tune 125BT, Branco-JBLT125BTWHT
# (Fone de Ouvido, Intra-Auricular, Bluetooth, JBL)
# Predicted: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 40, 'Conectividade'), (41, 44, 'Marca')]
# True: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (41, 44, 'Marca'), (45, 55, 'Modelo')]
#
#
# Headset Basic Conexão P3 Cabo de 150cm Cancelamento de Ruido Potência 45mw Preto - PH367
# (Headset, Basic Conexão P3 Cabo de 150cm, Cancelamento de Ruido, Potência 45mw, Preto, PH367)
# Predicted: [(0, 7, 'Categoria'), (8, 38, 'Modelo'), (39, 60, 'Categoria'), (61, 74, 'Caracteristicas'), (75, 80, 'Cor'), (83, 88, 'Modelo')]
# True: [(0, 7, 'Categoria'), (14, 24, 'Conectividade'), (25, 60, 'Caracteristicas'), (61, 74, 'Potência'), (75, 80, 'Cor')]
#
#
# Headphone Premium Bluetooth Large Preto - PH241
# (Headphone, Premium, Bluetooth, Large, Preto, PH241)
# Predicted: [(0, 9, 'Categoria'), (10, 17, 'Modelo'), (18, 27, 'Conectividade'), (28, 33, 'Modelo'), (34, 39, 'Cor'), (42, 47, 'Modelo')]
# True: [(0, 9, 'Categoria'), (10, 17, 'Modelo'), (18, 27, 'Conectividade'), (28, 33, 'Modelo'), (34, 39, 'Cor'), (42, 47, 'Modelo')]
#
#
# Fone JBL TWS Wave Buds, Auricular, Bluetooth, Preto - JBLWBUDSBLK
# (Fone JBL, TWS Wave Buds, Auricular, Bluetooth, Preto)
# Predicted: [(0, 8, 'Categoria'), (9, 22, 'Modelo'), (24, 33, 'Tipo'), (35, 44, 'Conectividade'), (46, 51, 'Cor')]
# True: [(0, 4, 'Categoria'), (9, 12, 'Caracteristicas'), (13, 22, 'Modelo'), (24, 33, 'Caracteristicas'), (35, 44, 'Caracteristicas'), (46, 51, 'Cor'), (54, 65, 'Modelo')]
#
#
# Caixa de Som Portátil JBL Clip 3 com Bluetooth Black
# (Caixa de Som, Portátil, JBL, Clip 3, Bluetooth, Black)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 32, 'Modelo'), (37, 46, 'Conectividade'), (47, 52, 'Cor')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 32, 'Modelo'), (37, 46, 'Conectividade'), (47, 52, 'Cor')]
#
#
# Tela De Projeção C/ Tripé 1,80x1,80m 97 Polegadas Retrátil - AC354
# (1,80x1,80m, Retrátil)
# Predicted: [(26, 36, 'Potência'), (50, 58, 'Caracteristicas')]
# True: [(0, 16, 'Categoria'), (20, 25, 'Item adicional'), (26, 36, 'Tamanho'), (37, 49, 'Tamanho'), (50, 58, 'Caracteristicas'), (61, 66, 'Modelo')]
#
#
# Caixa de Som Amplificada Amvox Aca-188 Gigante, 180W, Bluetooth, USB, Radio FM - Bivolt
# (Caixa de Som, Amplificada, Amvox, Aca-188, Gigante, 180W, Bluetooth, USB, Radio FM, Bivolt)
# Predicted: [(0, 12, 'Categoria'), (13, 24, 'Potência'), (25, 30, 'Marca'), (31, 38, 'Modelo'), (39, 46, 'Marca'), (48, 52, 'Potência'), (54, 63, 'Conectividade'), (65, 68, 'Conectividade'), (70, 78, 'Caracteristicas'), (81, 87, 'Tensão')]
# True: [(0, 12, 'Categoria'), (13, 24, 'Potência'), (25, 38, 'Caracteristicas'), (39, 46, 'Tamanho'), (48, 52, 'Potência'), (81, 87, 'Marca')]
#
#
# Caixa de Som JBL PartyBox 110 160W RMS Bluetooth LED Bateria 12h
# (Caixa de Som, JBL, PartyBox 110, 160W RMS, Bluetooth)
# Predicted: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 29, 'Modelo'), (30, 38, 'Potência'), (39, 48, 'Conectividade')]
# True: [(0, 12, 'Categoria'), (17, 29, 'Modelo'), (30, 38, 'Potência'), (39, 48, 'Conectividade')]
#
#
# Combo Kids - Fone De Ouvido Multilaser Kids Happy e KidWatch Infantil 4G + Wi-Fi Controle Parental Azul - P92001K
# (Combo Kids, Fone De Ouvido, Multilaser, Kids Happy e KidWatch, Wi-Fi, Azul)
# Predicted: [(0, 10, 'Categoria'), (13, 27, 'Categoria'), (28, 38, 'Marca'), (39, 60, 'Modelo'), (75, 80, 'Conectividade'), (99, 103, 'Cor')]
# True: [(0, 27, 'Categoria'), (28, 38, 'Marca'), (39, 69, 'Modelo'), (70, 72, 'Conectividade'), (75, 80, 'Conectividade'), (81, 98, 'Caracteristicas'), (99, 103, 'Cor'), (106, 113, 'Modelo')]
#
#
# Fone De Ouvido Multilaser Com Microfone Headfun Roxo P2 - PH090
# (Fone De Ouvido, Multilaser, Com Microfone, Headfun, PH090)
# Predicted: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 39, 'Caracteristicas'), (40, 47, 'Modelo'), (58, 63, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 39, 'Item adicional'), (40, 47, 'Modelo'), (48, 52, 'Cor'), (53, 55, 'Conectividade')]
#
#
# Fone de Ouvido Intra Auricular JBL T110 Preto - JBLT110BLK
# (Fone de Ouvido, Intra Auricular, JBL, T110, Preto, JBLT110BLK)
# Predicted: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 34, 'Marca'), (35, 39, 'Modelo'), (40, 45, 'Cor'), (48, 58, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 30, 'Tipo'), (31, 34, 'Marca'), (35, 39, 'Modelo'), (40, 45, 'Cor'), (48, 58, 'Modelo')]
#
#
# Fone De Ouvido Multilaser Headphone Hot Beat Branco Controle De Volume Haste Dobravel P2 - PH067
# (Fone De Ouvido, Multilaser, Headphone, Hot Beat, Branco, P2, PH067)
# Predicted: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 35, 'Tipo'), (36, 44, 'Modelo'), (45, 51, 'Cor'), (86, 88, 'Conectividade'), (91, 96, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 35, 'Tipo'), (36, 44, 'Modelo'), (45, 51, 'Cor'), (52, 85, 'Caracteristicas'), (86, 88, 'Conectividade'), (91, 96, 'Modelo')]
#
#
# Caixa De Som Bluetooth Wonderboom Raspberry Logitech
# (Caixa De Som, Bluetooth, Wonderboom, Raspberry, Logitech)
# Predicted: [(0, 12, 'Categoria'), (13, 22, 'Conectividade'), (23, 33, 'Modelo'), (34, 43, 'Modelo'), (44, 52, 'Marca')]
# True: [(0, 12, 'Categoria'), (13, 22, 'Conectividade'), (23, 43, 'Modelo'), (44, 52, 'Marca')]
#
#
# Fone De Ouvido Multilaser Headphone 360 Vermelho P2 - PH083
# (Fone De Ouvido, Multilaser, Headphone 360, Vermelho, P2, PH083)
# Predicted: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 39, 'Modelo'), (40, 48, 'Cor'), (49, 51, 'Conectividade'), (54, 59, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 25, 'Marca'), (26, 39, 'Modelo'), (40, 48, 'Cor'), (49, 51, 'Conectividade')]
#
#
# Caixa de Som JBL Bluetooth Flip 6, Estéreo, À Prova d'água, Preta - JBLFLIP6BLK
# (Caixa de Som, JBL, Bluetooth, Flip 6, À Prova d'água, Preta, JBLFLIP6BLK)
# Predicted: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 26, 'Conectividade'), (27, 33, 'Modelo'), (44, 58, 'Caracteristicas'), (60, 65, 'Cor'), (68, 79, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 16, 'Marca'), (17, 26, 'Conectividade'), (27, 34, 'Modelo'), (35, 42, 'Caracteristicas'), (44, 58, 'Caracteristicas'), (60, 65, 'Cor'), (68, 79, 'Modelo')]
#
#
# Vitrola Multifuncional ObaRetrô Obabox - 27716
# (Vitrola, Multifuncional, ObaRetrô Obabox, 27716)
# Predicted: [(0, 7, 'Categoria'), (8, 22, 'Modelo'), (23, 38, 'Modelo'), (41, 46, 'Potência')]
# True: [(0, 7, 'Categoria'), (8, 31, 'Modelo'), (32, 38, 'Marca'), (41, 46, 'Modelo')]
#
#
# Amplificador Frahm Profissional GR 5000
# (Amplificador, Frahm, Profissional GR 5000)
# Predicted: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 39, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 18, 'Marca'), (19, 39, 'Modelo')]
#
#
# Fone De Ouvido Bluetooth Mutop Vermelho - Rock
# (Fone De Ouvido, Bluetooth, Vermelho)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (31, 39, 'Cor')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (31, 39, 'Cor')]
#
#
# Fone de Ouvido Auricular JBL T215 TWS Branco
# (Fone de Ouvido, Auricular, JBL, T215, TWS, Branco)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 33, 'Modelo'), (34, 37, 'Conectividade'), (38, 44, 'Cor')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Tipo'), (25, 28, 'Marca'), (29, 33, 'Modelo'), (34, 37, 'Conectividade'), (38, 44, 'Cor')]
#
#
# Fone de Ouvido Bluetooth In-Ear JBL Live 300TWS Recarregável Resistente à Água, Branco-JBLLIVE300TWSWHT
# (Fone de Ouvido, Bluetooth, In-Ear, JBL, Resistente à Água)
# Predicted: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 31, 'Tipo'), (32, 35, 'Marca'), (61, 78, 'Caracteristicas')]
# True: [(0, 14, 'Categoria'), (15, 24, 'Conectividade'), (25, 60, 'Modelo'), (61, 78, 'Caracteristicas')]
#
#
# Earhook Sport Stereo Áudio - PH204
# (Earhook Sport Stereo Áudio, PH204)
# Predicted: [(0, 26, 'Modelo'), (29, 34, 'Modelo')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Marca'), (21, 26, 'Caracteristicas'), (29, 34, 'Modelo')]
#
#
# Headset Gamer Sony Pulse 3D para PS5
# (Headset, Gamer, Sony, Pulse, 3D, PS5)
# Predicted: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 18, 'Marca'), (19, 24, 'Marca'), (25, 27, 'Caracteristicas'), (33, 36, 'Conectividade')]
# True: [(0, 7, 'Categoria'), (8, 13, 'Caracteristicas'), (14, 18, 'Modelo'), (19, 24, 'Marca'), (33, 36, 'Conectividade')]
#
#
# Caixa de Som Portátil JBL GO 3 Bluetooth 5.1 À Prova D'água e Poeira IP67 Preto
# (Caixa de Som, Portátil, JBL, GO 3, Bluetooth 5.1, À Prova D'água e Poeira, IP67, Preto)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 30, 'Modelo'), (31, 44, 'Conectividade'), (45, 68, 'Caracteristicas'), (69, 73, 'Caracteristicas'), (74, 79, 'Cor')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Tipo'), (22, 25, 'Marca'), (26, 30, 'Modelo'), (31, 44, 'Conectividade'), (45, 68, 'Caracteristicas'), (69, 73, 'Caracteristicas'), (74, 79, 'Cor')]
#
#
# Kit Projetor 3500 Lumens Full HD com HDM +Tela de Projeção Retrátil
# (Kit Projetor, 3500 Lumens, Full HD, HDM +Tela de Projeção Retrátil)
# Predicted: [(0, 12, 'Categoria'), (13, 24, 'Potência'), (25, 32, 'Caracteristicas'), (37, 67, 'Conectividade')]
# True: [(0, 12, 'Categoria'), (13, 24, 'Potência'), (25, 32, 'Caracteristicas'), (33, 67, 'Item adicional')]
#
#
# Fone de Ouvido TWS Auricular JBL, Wave Buds, Branco - JBLWBUDSWHT
# (Fone de Ouvido, TWS, Auricular, JBL, Wave Buds, Branco, JBLWBUDSWHT)
# Predicted: [(0, 14, 'Categoria'), (15, 18, 'Conectividade'), (19, 28, 'Tipo'), (29, 32, 'Marca'), (34, 43, 'Modelo'), (45, 51, 'Cor'), (54, 65, 'Modelo')]
# True: [(0, 14, 'Categoria'), (15, 18, 'Conectividade'), (19, 28, 'Tipo'), (29, 32, 'Marca'), (34, 43, 'Modelo'), (45, 51, 'Cor'), (54, 65, 'Modelo')]
#
#
# Caixa de Som Acústica Multilaser SUNNY 12 Pol 400W BT/AUX/SD/USB/FM/LED – SP340
# (Caixa de Som, Acústica, Multilaser, SUNNY 12 Pol 400W, BT/AUX/SD/USB/FM/LED, SP340)
# Predicted: [(0, 12, 'Categoria'), (13, 21, 'Caracteristicas'), (22, 32, 'Marca'), (33, 50, 'Modelo'), (51, 71, 'Conectividade'), (74, 79, 'Modelo')]
# True: [(0, 12, 'Categoria'), (13, 21, 'Caracteristicas'), (22, 32, 'Marca'), (33, 45, 'Modelo'), (46, 50, 'Potência'), (51, 71, 'Conectividade'), (74, 79, 'Modelo')]
#
#
# MP4 8GB LCD 1.8
# (MP4, 8GB LCD 1.8)
# Predicted: [(0, 3, 'Categoria'), (4, 15, 'Modelo')]
# True: [(0, 3, 'Categoria'), (4, 7, 'Caracteristicas'), (8, 15, 'Caracteristicas')]
#
#
#                  precision    recall  f1-score   support
#
# Caracteristicas       0.68      0.55      0.61        55
#       Categoria       0.92      0.91      0.91       100
#   Conectividade       0.73      0.70      0.72        87
#             Cor       0.93      0.89      0.91        57
#  Item adicional       1.00      0.33      0.50         6
#           Marca       0.91      0.87      0.89        90
#          Modelo       0.66      0.62      0.64       133
#               O       0.00      0.00      0.00        92
#        Potência       0.79      0.67      0.72        33
#         Tamanho       0.33      0.11      0.17         9
#          Tensão       0.25      0.50      0.33         2
#            Tipo       0.90      0.93      0.92        29
#
#        accuracy                           0.65       693
#       macro avg       0.67      0.59      0.61       693
#    weighted avg       0.69      0.65      0.66       693

# %%
# Convert test data to spaCy Examples
examples = [Example.from_dict(nlp.make_doc(text), annotations) for text, annotations in test_data_spacy]

# Evaluate the model using SpaCy's built-in evaluate function
results = nlp.evaluate(examples)

# Print the evaluation results
print(f"Precision: {results['ents_p']:.4f}")
print(f"Recall: {results['ents_r']:.4f}")
print(f"F1-score: {results['ents_f']:.4f}")
print(f"Entity-wise results: {results['ents_per_type']}")
# Out:
# Precision: 0.7982
# Recall: 0.7438
# F1-score: 0.7700
# Entity-wise results: {'Categoria': {'p': 0.9191919191919192, 'r': 0.91, 'f': 0.9145728643216081}, 'Modelo': {'p': 0.6587301587301587, 'r': 0.6240601503759399, 'f': 0.6409266409266409}, 'Caracteristicas': {'p': 0.6818181818181818, 'r': 0.5454545454545454, 'f': 0.6060606060606061}, 'Potência': {'p': 0.7857142857142857, 'r': 0.6666666666666666, 'f': 0.721311475409836}, 'Conectividade': {'p': 0.7349397590361446, 'r': 0.7011494252873564, 'f': 0.7176470588235295}, 'Marca': {'p': 0.9069767441860465, 'r': 0.8666666666666667, 'f': 0.8863636363636364}, 'Tipo': {'p': 0.9, 'r': 0.9310344827586207, 'f': 0.9152542372881356}, 'Cor': {'p': 0.9272727272727272, 'r': 0.8947368421052632, 'f': 0.9107142857142856}, 'Item adicional': {'p': 1.0, 'r': 0.3333333333333333, 'f': 0.5}, 'Tamanho': {'p': 0.3333333333333333, 'r': 0.1111111111111111, 'f': 0.16666666666666666}, 'Tensão': {'p': 0.25, 'r': 0.5, 'f': 0.3333333333333333}}

# %%
# Example text to test the model
doc = nlp("Fone JBL TWS Wave Buds, Auricular, Bluetooth, Preto - JBLWBUDSBLK")

# Print the entities recognized by the model
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Fone JBL 0 8 Categoria
# TWS Wave Buds 9 22 Modelo
# Auricular 24 33 Tipo
# Bluetooth 35 44 Conectividade
# Preto 46 51 Cor
